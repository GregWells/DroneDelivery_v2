# %%
import copy
#from copy import deepcopy

global PSEUDO,PSEUDOORDERLIMIT
PSEUDO=True
PSEUDOORDERLIMIT=2
DEBUG=True
filename="busy_day.in"
#filename="/kaggle/input/hashcode-drone-delivery/busy_day.in"
import time
#Start the timer
start_time = time.time()

import gym
from gym import spaces
from gym.spaces import MultiDiscrete

import random
import math
from itertools import combinations
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
import scipy.spatial
import scipy.spatial.distance as distance

from icecream import ic
from operator import itemgetter


########### Functions   ##################
def writeLog():
    #Now pad drones with wait times commensurate with how early they finished.
    #The last destTime is?
    maxDestTime,maxDroneNum=max([  (d[x].getDestTime(),ind) for ind,x in enumerate(  range( Drone.getQty() )  ) ])
    print("Drone:{} was the last to finish. The finish time was:{} ".format(maxDroneNum,maxDestTime))
    #for i in range(Drone.getQty()):
    #    destTime=d[i].getDestTime()
    #    padTime=deadline-destTime
    #    if padTime>0:
    #        print("Padding drone:{} with {} units of time".format(i,padTime))
    #        l.append(Log(str(i)+" W "+str(padTime)))
    #    else:
    #        print("No padding required for drone:{} as it was the last to finish".format(i))
    outputFile = open("submission.csv", "w")
    #outputFile = open("/kaggle/working/submission.csv", "w")

    result=outputFile.write( str( Log.getCount()+ Drone.getQty())+'\n'  )
    for i in range(Log.getCount()):
        result=outputFile.write(l[i].getLine()+'\n')
    for i in range(Drone.getQty()):
        destTime=d[i].getDestTime()
        padTime=deadline-destTime
        if padTime>0:
            print("Padding drone:{} with {} units of time".format(i,padTime))
            #l.append(Log(str(i)+" W "+str(padTime)))
            result=outputFile.write(str(i)+" W "+str(padTime) +"\n")
    outputFile.close()
    return 
 
def dist(p1, p2):
    (x1, y1), (x2, y2) = p1, p2
    return math.sqrt((x2 - x1)**2 + (y2 - y1)**2)

def distToLine(x1, y1, x2, y2, x3, y3): # x1,y1 one end of line segment x2,y2 other end; x3,y3 is the point
    px = x2-x1
    py = y2-y1
    norm = px*px + py*py
    u =  ((x3 - x1) * px + (y3 - y1) * py) / float(norm)
    if u > 1:
        u = 1
    elif u < 0:
        u = 0

    x = x1 + u * px
    y = y1 + u * py
    dx = x - x3
    dy = y - y3
    # Note: If the actual distance does not matter,
    # if you only want to compare what this function
    # returns to other results of this function, you
    # can just return the squared distance instead
    # (i.e. remove the sqrt) to gain a little performance
    dist = (dx*dx + dy*dy)**.5
    return dist
def createOrdArray():
    global ordArray,ordArrayMaster
    ordArrayMaster_exists = 'ordArrayMaster' in locals() or 'ordArrayMaster' in globals()
    if ordArrayMaster_exists:
        #print("ordArrayMaster already exists, using a prior copy for expediency")
        #If this has already been run, then restore the previously stored objects
        ordArray=copy.deepcopy(ordArrayMaster)
        return
    else:
        print("ordArrayMaster doesnt exist yet. Make a master and a copy ")
    # create a table of each order and its distance from a line connecting each two warehouse pairs
    #This will be used to select optimal flight/delivery paths on intermodal flights
    #Sorting the array by a given column (where prod is not fulfilled) and selecting the smallest value
    # results in an ordernum that is nearest the beeline
    #Cols: orderNum, r,c,weight,fulfilled,inStock,0to0,0to1,1to1,...
    #if the warehouses are the same, use the order distance to the wh point/location
    import numpy as np

    # creating an empty 2d array of int type
    #cols=orderNum,r,c,weight,fulfilled,distFrom0to1line,
    
    ordArray = np.empty((0,106), int)
    #ordArray=ordArray.reshape((0, 105))
    #ordArray=np.append(ordArray,np.zeros((105,), dtype=int))
    # using np.append()
    for i in range(len(order)):
        ordList=list()
        #ordArray=np.append(ordArray,np.zeros((105,), dtype=np.int32))
        r,c=order[i].getPos()
        wt=order[i].getWeight()
        _,wh=order[i].getAssignedItem() 
        assignedWh=order[i].getWh()
        if wh!=assignedWh:
            intermodal=1
        else:
            intermodal=0
        if order[i].isFulfilled() or order[i].isLoaded(): 
            fulfilled=1
        else:
            fulfilled=0
        ordList.extend([i,r,c,wt,fulfilled,intermodal])
        for j in range(10):
            wr1,wc1=w[j].getPos()
            for k in range(10):
                wr2,wc2=w[k].getPos()
                #ordArray[i][5+j*10+k]=distToLine(wr1,wc1,wr2,wc2,r,c)
                if j!=k:
                    ordList.append(int(distToLine(wr1,wc1,wr2,wc2,r,c)))
                else:
                    ordList.append(int(dist((wr1,wc1),(r,c))))
        ordArray=np.append(ordArray,ordList)
    ordArray.shape=(len(order),106)
    ordArrayMaster=copy.deepcopy(ordArray)
    return

def closestToBeeline(wh1,wh2):
    colNum=6+wh1*10+wh2
    #a[a[:,2].argsort()]           #sort by the 3rd column ascending
    #a[a[:,2].argsort()][::-1]     #sort by the 3rd column descending
    #first sort by weight(ascending),then by dist from beeline(ascending), then by fulfilled(ascending?)
    
    #ordArray=ordArray[ordArray[:,3].argsort()] #weight
    #ordArray=ordArray[ordArray[:,colNum].argsort()] #distance
    #ordArray=ordArray[ordArray[:,4].argsort()] #isFulfilled
    ind = np.lexsort((ordArray[:,5],ordArray[:,4],ordArray[:,3],ordArray[:,colNum]))
    #ic(colNum)
    #use ordArray[i][colNum] for selection
    return ind    

def wishList(needyWh,donorWh):  #create wish list for needyWh of orders that reside in donorWh
    orderList=list()
    ec=200
    for i in range(Order.getQty()):
        if ec<2:
            break
        if order[i].getWh()!=needyWh or order[i].isFulfilled()==True:
            continue
        itemIndex,wh=order[i].getAssignedItem() 
        if wh!=donorWh or order[i].getWeight()>ec:
            continue
        orderList.append(i)
        ec=ec-order[i].getWeight()
        #order[i].showStatus()
    #print("OrderList:{}".format(orderList)) 
    return orderList
def closestToWh(wh):  #sort by closest-to-wh,wt,filled,intermodal
    colNum=6+wh*10
    ind = np.lexsort( (ordArray[:,5],ordArray[:,4],ordArray[:,3],ordArray[:,colNum]) )
    #use ordArray[i][colNum] for selection
    return ind   #This returns a list of indicies. Use by selecting ordArray[ind]

def ordersInRadius(wh,r):    #Usage ordersInRadius(2,30)
    wr,wc=w[wh].getPos()
    oir=np.count_nonzero(np.logical_and ( ( (ordArray[:,1]-wr)**2 + (ordArray[:,2]-wc)**2 <r**2) ,  ordArray[:,4]==0)) 
    if  oir>0:
        return int(math.log(oir) )
    else:
        return 0
def ordersInRadius2(wh,r):    #Usage ordersInRadius(2,30)
    wr,wc=w[wh].getPos()
    oir2= np.count_nonzero(  (ordArray[:,1]-wr)**2 + (ordArray[:,2]-wc)**2 <r**2 )
    if  2>0:
        return int(math.log(oir2) )
    else:
        return 0
def ordersUnfilled(wh):    #Usage ordersUnfilled(2)
    unfilledOrderCount=0
    for i in range(Order.getQty()):
        if order[i].getWh()==wh and not order[i].isFulfilled() and not order[i].isLoaded():
            unfilledOrderCount+=1
    if  unfilledOrderCount>0:
        return int(math.log(unfilledOrderCount) )
    else:
        return 0

def ordersInStockClose(wh,r):
    wr,wc=w[wh].getPos()
    oisc= np.count_nonzero(np.logical_and ( ( (ordArray[:,1]-wr)**2 + (ordArray[:,2]-wc)**2 <r**2) ,  ordArray[:,4]==0,ordArray[:,5]==0)) 
    if  oisc>0:
        return int(math.log(oisc) )
    else:
        return 0
def ordersInStockFar(wh,r):
    wr,wc=w[wh].getPos()
    oisf=np.count_nonzero(np.logical_and ( ( (ordArray[:,1]-wr)**2 + (ordArray[:,2]-wc)**2 >=r**2) ,  ordArray[:,4]==0,ordArray[:,5]==0)) 
    if  oisf>0:
        return int(math.log(oisf) )
    else:
        return 0
def dronesInRadius(wh,r):    #Usage dronesInRadius(2,30)
    count=0
    wr,wc=w[wh].getPos()
    for i in range(Drone.getQty()):
        dr,dc=d[i].getDest()
        if ((dr-wr)**2 + (dc-wc)**2 <r**2 ):
            count+=1
    if count>0:
        return int(math.log(count))
    else:
        return 0

def knn(x, X, k, **kwargs):
    """
    find indices of k-nearest neighbors of x in X
    """
    d = distance.cdist(x.reshape(1,-1), X, **kwargs).flatten()
    return np.argpartition(d, k)[:k]

def consumeInputFile2():
    global ordMaster,itemMaster,whMaster,droneMaster,prodMaster
    global prodWeight,item,warehouse,drone,locations,priorDroneCmd
    global whProdOffset,dronePayloadOffset
    global gridRows,gridCols, droneQty,deadline,maxLoad,whLocs
    global w, p, d, order, l
    
    ordMaster_exists = 'ordMaster' in locals() or 'ordMaster' in globals()
    if ordMaster_exists:
        #print("ordMaster already exists, using a prior copy for expediency")
        #If this has already been run, then restore the previously stored objects
        order=copy.deepcopy(ordMaster)
        item=copy.deepcopy(itemMaster)
        w=copy.deepcopy(whMaster)
        d=copy.deepcopy(droneMaster)
        p=copy.deepcopy(prodMaster)
        return

    
    locations={}
    item=list()
    w=list()
    l=list()
    locationCounter=0
    #read datafile
    filename="busy_day.in"
    #filename="/kaggle/input/hashcode-drone-delivery/busy_day.in"
    #raise SystemExit("Stop right here to evaluate! {}".format(filename))

    with open(filename) as fp:
        line = fp.readline()
        line=line.strip()
        phase = 0
        
        while line: 
            #print("Executing section {} of input file {}: {}".format(phase,filename, line.strip()))
            if phase==0:
                rows,cols,droneqty,deadline,maxLoad=line.split(maxsplit=5)
                gridRows=int(rows)
                gridCols=int(cols)
                #print("gridRows:{} ,gridCols:{}".format(gridRows,gridCols))
                droneqty=int(droneqty)
                deadline=int(deadline)
                maxLoad=int(maxLoad)
            elif phase==1:  ########  Simulation  parameters  ##############
                #print(line)

                minItemWeight=maxLoad   #tune this downward as items are processed
                totalProductTypes=int(line)
                line = fp.readline()
                productWeightList = line.split()  #this is a list of product weights

                p=[0]*(totalProductTypes)  #create a list of productType object names
                
                

                for productNum in range(totalProductTypes):
                    #instantiate each product
                    thisWeight=int(productWeightList[productNum])
                    if minItemWeight>thisWeight:
                        minItemWeight=thisWeight
                    #ic(ProductType(productNum,thisWeight))
                    #raise SystemExit("Stop right here to evaluate! 3c")
                    p[productNum]=ProductType(productNum,thisWeight)
                    
                    #print("productNum:{},Weight:{} ".format(productNum,thisWeight) )
                    #pass
                #phase +=1

            elif phase==2:   ########  Warehouse detail  ##############

                whQty=int(line)
                whDict={}
                whLocs=list()
                w=[0]*(whQty)  #create a list of warehouse object names
                for warehouseNum in range(whQty):
                    line = fp.readline()
                    r,c = line.split()
                    r,c=int(r),int(c)
                    locations.update({(r,c):locationCounter})
                    locationCounter+=1
                    w[warehouseNum]=Warehouse(warehouseNum,r,c)
                    whLocs.append(  (r,c)  )
                    whDict[(r,c)]=warehouseNum
                    line = fp.readline()
                    for productNum,productQty in enumerate(line.split()):
                        productNum,productQty=int(productNum),int(productQty)
                        #instantiate quantity of each product for this warehouse
                        #print("Warehouse:{}   productNum:{}  qty:{}".format(warehouseNum,productNum,productQty))
                        #itemQuantity=item.getQty()
                        for i in range(productQty):
                            item.append(Item(productNum,'W',warehouseNum,p[productNum].getWeight()))
                        pass
                    #Validate all products are listed in the input file
                    if productNum+1!= totalProductTypes:
                        print("ERROR:  Invalid input file load for warehouse: {} productNum={}".format(warehouseNum,productNum))
                        break
                #print("warehouse Locations:{}".format(whLocs))
                #compute average distance btw warehouses
                points=whLocs
                distances = [Calculate.dist(p1, p2) for p1, p2 in combinations(whLocs, 2)]
                avg_distance = sum(distances) / len(distances)
                #print("avg_distance btw warehouses:{}".format(avg_distance))
                closeDist=avg_distance/2
                #instantiate drones
                row,col=w[0].getPos()
                d=list()
                for i in range(int(droneqty)):
                    d.append(Drone(row,col,maxLoad))
                    d[i].setDest(row,col)
                    #ic(d[i].getDest())
            elif phase==3:  ########  Customer orders   ##############
                totalOrders=int(line)
                #print("There are {} total orders".format(totalOrders))
                allOrderlocs=list()
                order=list()  #create a list of order object names
                for orderNum in range(totalOrders):

                    line = fp.readline()
                    r,c = line.split()
                    r,c = int(r),int(c)
                    orderTup=(r,c)
                    if orderTup not in locations.keys():               #some orders are for repeat cust, so not at new loc
                        locations.update({orderTup:locationCounter})
                        locationCounter+=1
                    line = fp.readline()
                    orderQty = int(line)
                    #order[orderNum]=Order(orderNum,r,c)
                    line = fp.readline()
                    if PSEUDO:
                        if orderNum<=PSEUDOORDERLIMIT:
                            #orderedProducts=line.split()
                            prodNums = [int(x) for x in line.split()]
                            for index in range(orderQty):
                                #instantiate order
                                allOrderlocs.append( (r,c) )
                                weight=p[prodNums[index]].getWeight()
                                orderIndex=Order.getQty()
                                order.append(Order(orderNum,r,c,prodNums[index],orderQty,weight))
                            #DEBUG and print("OrderNum {}: Cust: {},{}  Line Items:{} ".format(orderNum, r,c,orderQty,line))
                    else:
                        #orderedProducts=line.split()
                        prodNums = [int(x) for x in line.split()]
                        for index in range(orderQty):
                            #instantiate order
                            allOrderlocs.append( (r,c) )
                            weight=p[prodNums[index]].getWeight()
                            orderIndex=Order.getQty()
                            order.append(Order(orderNum,r,c,prodNums[index],orderQty,weight))
                        #DEBUG and print("OrderNum {}: Cust: {},{}  Line Items:{} ".format(orderNum, r,c,orderQty,line))
                break
            phase +=1
            line = fp.readline()  #read next line
            line=line.strip()
        #raise SystemExit("Stop right here to evaluate! 4")
        
    fp.close()
    
    
    #print("{} extra lines in input file".format(counter))  
    #print("Max Payload:{}".format(maxLoad))
    #raise SystemExit("Stop right here to evaluate! 3")

    #totalItemsInSim=Item.getQty()
    #print("Total Items available in warehouses:{}".format(Item.getQty()))

    ##### Show what was loaded from input file
    #for i in range(Drone.getQty()):
        #d[i].showStatus()
    #    pass   
    #for productNum in range(totalProductTypes):
        #num,weight=p[productNum].getStatus()
        #print("Product:{}  Weight:{}".format(num,weight))
    #    pass
    #for whn in range(whQty):
    #    itemCount=w[whn].getInventory(item,Item.getQty())
        #print("Warehouse:{} has {} items".format(whn,itemCount))
    #    pass
    #print("Order qty:{}".format(Order.getQty()))   

    #for i in range(395,410):
        #item[i].showStatus()
    #    pass
    #for i in range(10):
    #    orderIndex,r,c,orderNum,prodNum,remItems=order[i].getStatus()
        #print("orderIndex:{} orderNum:{}  r:{} c:{}  prodNum:{} remItems:{}".format(orderIndex,orderNum,r,c,prodNum,remItems))
    #    pass

    #for i in range(Order.getQty()):
    #    if order[i].getRemItems()>8:
    #        print(i,"  ",order[i].getRemItems())

    #################################################################
    ####                 Warehouse assignments             ##########
    #################################################################


    #First assign each order to a warehouse based on proximity 
    #later an ML will determine assignment

    for i in range(Order.getQty()):
        r,c=order[i].getPos()
        order[i].setWh(Calculate.nearestWh(r,c )  )
    #print("Order qty:{}".format(Order.getQty()))

    count=0
    for i in range(Order.getQty()):
        count+=1
        r,c=order[i].getPos()
        #print(order[i].getWh( )  ,end='' )                     

    ########## for each warehouse, assign existing product-items to a specific order ###########
    origInStockCounter=0
    origInStockList=list()
    intermodalListCounter=0
    #first create a list of every order based on distance to warehouse
    for wh in range(whQty):
        print("Warehouse {}".format(wh))
        wr,wc=w[wh].getPos()
        thisWhOrderList=Calculate.getAllOrdersForWh(wh)

        #Starting with the closest, assign specific items to orders
        for orderTup in thisWhOrderList:

            orderIndex,_=orderTup
            #print("orderIndex {}".format(orderIndex))
            #if the order does not yet have an item assignment...
            if not order[orderIndex].isAssigned():
                #print("orderIndex {} is not assigned".format(orderIndex))
                prodNum=order[orderIndex].getProdNum()
                #print("prodNum {} ".format(prodNum))

                # if the item is in stock at the designated warehouse then assign it

                #review products in this warehouse, if available, then assign it
                warehousesWithThisProd=list()
                foundLocally=False
                for i in range( Item.getQty() ):
                    itemIndex,pn,facType,facIndex,assigned=item[i].getStatus2()
                    if facType=='W'  and pn==prodNum and assigned==False :
                        #print("===>",'W',facType,wh,facIndex,facType=='W',facIndex==wh,pn==prodNum )

                        if wh==facIndex:
                            #print("origInStockCounter:{}".format(origInStockCounter))
                            foundLocally=True
                            origInStockCounter+=1
                            #assign this item to this order
                            item[itemIndex].assignToOrder(orderIndex)
                            order[orderIndex].setAssignedItem((itemIndex,wh))
                            wr,wc=w[wh].getPos()
                            r,c=order[orderIndex].getPos()
                            dist=math.ceil( Calculate.distance(r,c,wr,wc) )
                            origInStockList.append(orderIndex)
                            #print("Item {} Instock at local wh:{} dist:{}".format(itemIndex,wh,dist))
                            break
                if not foundLocally:
                    for i in range( Item.getQty() ):
                        itemIndex,pn,facType,facIndex,assigned=item[i].getStatus2()
                        if facType=='W'  and pn==prodNum and assigned==False :
                            #print(facIndex,type(facIndex),wh,type(wh),facIndex==wh )
                            warehousesWithThisProd.append(facIndex)

                    warehousesWithThisProd=list(set(warehousesWithThisProd))
                    #print("Warehouses with this prod:{}".format(warehousesWithThisProd))
                    closestWh=Calculate.nearestWh(wr,wc,warehousesWithThisProd )
                    #print("Assigning closest wh:{}".format(closestWh))
                    #print("product:{} not found locally in wh:{} --> closest wh:{}".format(prodNum,wh,closestWh))
                    #Find an available item. Search all available items with loc= chosen wh
                    itemIndex=Calculate.findAvailProdInWh(prodNum,closestWh)
                    item[itemIndex].assignToOrder(orderIndex)

                    order[orderIndex].setAssignedItem(  (itemIndex,closestWh)  )
                    #DEBUG and print("Order:{} being assigned item:{} NOT in wh:{} --> closest wh:{}".format(orderIndex,itemIndex,wh,closestWh))
                    #print("-",end='')
                    w[wh].addToIntermodalList(  (closestWh,orderIndex,itemIndex)      )
                    intermodalListCounter+=1

    #print("Items originally in stock: {}  Intermodal list:{}".format(origInStockCounter, intermodalListCounter))
    #Check for orders without an assigned product
    for orderIndex in range( Order.getQty() ):
        if order[orderIndex].isAssigned() == False:
            print("order[{}] has not been assigned an item ".format(orderIndex))
            raise SystemExit("Stop right here to evaluate!") 

        else:
            #print("=",end='')
            pass
    print("\n\n")

    #for wh in range(whQty):
    #    print("Warehouse:{} Intermodal list length:{}".format(wh,len(w[wh].getIntermodalList())))

    ordMaster=copy.deepcopy(order)
    itemMaster=copy.deepcopy(item)
    whMaster=copy.deepcopy(w)
    droneMaster=copy.deepcopy(d)
    prodMaster=copy.deepcopy(p)
    return 


class DroneEnv(gym.Env):
    def __init__(self):
        super(DroneEnv, self).__init__()
        self.name="parent object to contain data and algorithm subclasses"
        self.manifestSeqNum=0
        self.total_reward=0
        self.droneqty=None
        self.totalOrders=None
        self.max_weight=None
        global deadline,log
        #deadline=99999
        l=list()
        #l[self.manifestSeqNum]=Log(logstring)

        #raise SystemExit("Stop right here to evaluate!")

        #consumeInputFile2()
        
        #self.LUDWoptions=3
        #deadline=int(deadline* (self.totalOrders/9400))
        #[ priorDroneCmd.update({x:3}) for x in range(30) ] 
        # Define action and observation space
        # They must be gym.spaces objects
        
        #action position 0=drone , pos 1=LUDW, pos 2=order or warehouse ,pos 4=prodNum
        #print("self.action_space = gym.spaces.MultiDiscrete([ {} ])".format(2,3,self.orderIndex,self.totalProductTypes) )
        #self.action_space = gym.spaces.MultiDiscrete([1,self.LUDWoptions,len(locations),self.totalProductTypes])
        #To verify the environment works correctly, change the first value in the action space to 1 or 2 (drone qty)
        #starting Wh,ending Wh(vicinity), flight type (0=local:1=intermodal:2=mixed)
        self.action_space = gym.spaces.MultiDiscrete([10,10],dtype=np.int32)

        #self.action_space = gym.spaces.MultiDiscrete([self.droneqty,3,self.orderIndex,self.totalProductTypes])
        
        #print("                                                ManSeq#,orders_Completed,#drones,Drone@Loc,PayloadWeight,priorCmd,currentCmd ])" )
        #print("self.observation_space = gym.spaces.MultiDiscrete([ {},{},{},{},{},{},{} ])".format(len(orders)*5,self.orderIndex+1,self.droneqty+1,self.locationCounter+1,maxLoad+2,3,3) )

        self.observation_space =gym.spaces.MultiDiscrete([4000,31,11,
                                                                    11,11,11,11,11,
                                                                    11,11,11,11,11,
                                                                    11,11,11,11,11,
                                                                    11,11,11,11,11,
                                                                    11,11,11,11,11,
                                                                    11,11,11,11,11,
                                                                    11,11,11,11,11,
                                                                    11,11,11,11,11,
                                                                    11,11,11,11,11,
                                                                    11,11,11,11,11],dtype=np.int32)
        #print("Step observation:  shape:{} ".format(observation.shape))          
        #print("observation type:{} ".format(type(observation)))
        #ic(self.observation_space)
        #obs space( ManifestNum, )
        #self.observation_space =gym.spaces.MultiDiscrete([len(orders),self.orderIndex+1,self.droneqty+1,self.locationCounter+1,maxLoad+1,int(4),int(4)])

    def showStatus(self,val=None):
        if val==None:
            rangeval=range(self.droneqty)
        else:
            rangeval=range(val,val+1)
        for i in rangeval:
            print("Drone:{} ".format(i),end=' ')
            for c in range (15):
                print(drone[i][c],end=' ')
            print( "    Excess Capacity:{}".format(maxLoad-sum([prodWeight[x] for x in filter(None,drone[i][dronePayloadOffset:15]) ]))) 
            #print("")
        print("")
    def getDroneLoc(self,droneNum):
        self.droneLoc=locations[drone[droneNum][2:4]]
        return self.droneLoc
    def getPayloadItems(self,droneNum):    
        self.payloadItems=len([self.x for self.x in drone[droneNum][5:15] if self.x!=None] )#last is # of items onboard  
        return self.payloadItems
    def resetManifestSeqNum(self):
        self.manifestSeqNum=0
    def getManifestSeqNum(self):
        return self.manifestSeqNum
    def incManifestSeqNum(self):
        self.manifestSeqNum+=1
    def getMacroScore(self):
        return self.macroScore
    def incMacroScore(self):
        self.macroScore+=1
    def resetMacroScore(self):
        self.macroScore==0
    def getWarehouseLoc(self,wh):
        return warehouse[wh][0:2]
    def getOrigOrderNum(self,val):
        self.origOrderNum=orders[val][5]
        return self.origOrderNum
    def getOrderLoc(self,val):
        return orders[val][0:2]
    
        
    def step(self, action):   #startWh, endWh, manifest type 0=local:1=intermodal:2=mixed
        #get next drone number for next step
        destTime,self.droneNum=min([  (d[x].getDestTime(),ind) for ind,x in enumerate(  range( Drone.getQty() )  ) ])
        Calculate.setCurrentTime(destTime)
        #self.startWh=action0
        #self.endWh=action1
        #self.manifestType=action2
        time =Calculate.getCurrentTime()
        
        
        actionList=list(action)
        #self.prev_actions.append(self.actionList)
        self.done=False
        self.reward=0
        self.manifestDistance=0
        #print("NextCommand:{}, {}, {}, {}:".format(nextCommand[0],nextCommand[1],nextCommand[2],nextCommand[3] ) )
        #manifestSeqNum,microScore,macroScore,droneNum,droneLoc,payloadItems=simAction(nextCommand)    
        
        
        #result=simAction(nextCommand[0],nextCommand[1],nextCommand[2],nextCommand[3]) 
        self.startWh=int(actionList[0])
        self.endWh=int(actionList[1])
        #self.manifestType=actionList[2]
        #print("Start:{}  End:{}    Equal:{} ".format(self.startWh,self.endWh, (self.startWh==self.endWh) ))
        ################################################################################
        ##############       Deliver near a given warehouse              ###############
        ################################################################################
        if self.startWh==self.endWh:   #Pick closest (unfulfilled) order to startWh, and 2nd closest under weight limit for last
            #mark the drone loc for the warehouse dest
            wr,wc=w[self.startWh].getPos()
            dr,dc=d[self.droneNum].getDest() 
            d[self.droneNum].setDest(wr,wc)
            segmentDist=math.ceil(dist((dr,dc),(wr,wc))) + 1 
            self.manifestDistance+=segmentDist 
            #mark the drone as enroute
            d[self.droneNum].setEnRoute(True)
            #mark the drone desttime for the warehouse dest
            thisDroneTime=d[self.droneNum].getDestTime()
            d[self.droneNum].setDestTime(thisDroneTime+segmentDist )
            
            
            ec=maxLoad
            loadManifest=list()
            ind=closestToWh(self.startWh)
            #get first order from index that is avail (should be the first one as that's how the list is sorted)
            for i in ind:
                # Remove the FIRST element from ind using slicing 
                ind = ind[1:]
                if not order[i].isFulfilled() and not order[i].isLoaded():
                    break
            firstDelivery=i
            ec=ec-order[i].getWeight()
            loadManifest.append(i)
            #unloadManifest.append(i)
            #mark as unavailable
            order[i].setLoaded(True)
            ordArray[i][4]=1
            #now find the next closest order to the wh under the excess capacity 
            #this should be the last stop for this manifest 
            for i in ind:
                # Remove the FIRST element from ind using slicing 
                ind = ind[1:]
                if order[i].getWeight() <=ec and not order[i].isFulfilled() and not order[i].isLoaded():
                    break
            ec=ec-order[i].getWeight()
            loadManifest.append(i)
            #unloadManifest.append(i)
            #mark as unavailable
            order[i].setLoaded(True)
            ordArray[i][4]=1
            
            #Now find the closest to the first delivery
            cr,cc=order[firstDelivery].getPos()
            cluster=ordArray[:, [0,1,2,3,4,5]]
            clusterArray=cluster[( (cr-cluster[:,1]) **2+ (cc-cluster[:,2])**2).argsort()  ] 
            for i in ind:
                if ec<2 :
                    break
                if clusterArray[i][3]<=ec and clusterArray[i][4]==0 and clusterArray[i][5]==0:
                    ec=ec-order[i].getWeight()
                    loadManifest.append(i)
                    #unloadManifest.append(i)
                    #mark as unavailable
                    order[i].setLoaded(True)
                    ordArray[i][4]=1 
                    clusterArray[i][4]=1
            #Manifests are complete, so put the manifest in the right order for shortest path   
            #for now, move the second item to the end
            x=loadManifest.pop(1)
            loadManifest.append(x)

            for orderNum in loadManifest:
                #mark each order in the manifest as loaded; 
                pn=order[orderNum].getProdNum()
                order[orderNum].setLoaded(True)
                order[orderNum].setDeliveryInProcess(True)
                assignedItem,wh=order[orderNum].getAssignedItem()
                #update each item to 'D' ,droneNum
                item[assignedItem].load('D',self.droneNum)
                l.append(Log(str(self.droneNum)+" L "+str(self.startWh)+" "+str(pn)+" 1"))
                
            #Now deliver    
            for orderNum in loadManifest:
                #mark each order in the manifest as delivered;
                dr,dc=d[self.droneNum].getPos()
                r,c=order[orderNum].getPos()
                
                segmentDist=math.ceil(dist((dr,dc),(r,c)))
                #Add 1 time unit for a stop to unload
                if (dr,dc)!=(r,c):
                    segmentDist+=1
                self.manifestDistance+=segmentDist 
                d[self.droneNum].setDest(r,c)
                #mark the drone desttime for the warehouse dest
                thisDroneTime=d[self.droneNum].getDestTime()
                d[self.droneNum].setDestTime(thisDroneTime+segmentDist )
                #d[self.droneNum].setDestTime(Calculate.getCurrentTime()+segmentDist )
                
                order[orderNum].setLoaded(False)
                order[orderNum].setFulfilled(d[self.droneNum].getDestTime(),order[orderNum].getAssignedItem())
                #order[orderNum].isFulfilled(True)
                assignedItem,wh=order[orderNum].getAssignedItem()
                order[orderNum].setFulfilled(Calculate.getCurrentTime(),assignedItem)
                ordArray[orderNum][4]=1 
                clusterArray[orderNum][4]=1
                #update each item to 'D' ,droneNum
                item[assignedItem].setCustDelivery(orderNum)
                # score it
                self.reward+=(  (deadline-(Calculate.getCurrentTime()+segmentDist))/deadline) *100 
                pn=order[orderNum].getProdNum()
                origOrderNum=order[orderNum].getOrderNum()
                l.append(Log(str(self.droneNum)+" D "+str(origOrderNum)+" "+str(pn)+" 1"))
            #Done with delivery
            d[self.droneNum].setEnRoute(False)
            #mark the drone desttime for the warehouse dest
            #mark the drone loc for the last order dest
            #mark the drone as avail (not enroute)


          
        

        ################################################################################
        ##############              Intermodal Delivery                  ###############
        ################################################################################  
        elif self.startWh!=self.endWh:  
            #retrieve a list of items (within excess capacity)needed in endWh that are available in startWh
            needyWh,donorWh=self.startWh,self.endWh
            loadManifest=wishList(needyWh,donorWh)
            if len(loadManifest)>0:
                #calculate the distance to the donor warehouse
                #mark the drone loc for the donor warehouse 
                wr,wc=w[donorWh].getPos()
                dr,dc=d[self.droneNum].getDest() 
                d[self.droneNum].setDest(wr,wc)
                segmentDist=math.ceil(dist((dr,dc),(wr,wc)))
                #Add 1 time unit for a stop to unload
                if (dr,dc)!=(wr,wc):
                    segmentDist+=1
                self.manifestDistance+=segmentDist 
                #mark the drone as enroute
                d[self.droneNum].setEnRoute(True)
                #mark the drone desttime for the warehouse dest
                d[self.droneNum].setDestTime(Calculate.getCurrentTime()+segmentDist )
                
                #Now load the items
                for orderNum in loadManifest:
                    order[orderNum].setLoaded(True)
                    ordArray[orderNum][4]=1
                    pn=order[orderNum].getProdNum()
                    l.append(Log(str(self.droneNum)+" L "+str(donorWh)+" "+str(pn)+" 1"))
                    
                #mark the drone loc for the warehouse dest
                wr,wc=w[needyWh].getPos()
                dr,dc=d[self.droneNum].getDest() 
                d[self.droneNum].setDest(wr,wc)
                segmentDist=math.ceil(dist((dr,dc),(wr,wc))) + 1 
                self.manifestDistance+=segmentDist 
                #mark the drone as enroute
                d[self.droneNum].setEnRoute(True)
                #mark the drone desttime for the warehouse dest
                d[self.droneNum].setDestTime(Calculate.getCurrentTime()+segmentDist )
                
                #Now unload the items
                for orderNum in loadManifest:
                    order[orderNum].setLoaded(False)
                    ordArray[orderNum][4]=0
                    ordArray[orderNum][5]=0  #Mark as no longer intermodal
                    #change to order assignedItem to reflect the new wh location
                    itemIndex,_=order[orderNum].getAssignedItem()
                    order[orderNum].setAssignedItem((itemIndex,needyWh))
                    #change the item to the new location
                    item[itemIndex].setLoc('W',needyWh)
                    self.reward+=1
                    pn=order[orderNum].getProdNum()
                    l.append(Log(str(self.droneNum)+" U "+str(needyWh)+" "+str(pn)+" 1"))
                #Done with delivery
                d[self.droneNum].setEnRoute(False)
        #self.droneLoc=locations[drone[self.droneNum][2:4]]    


        info = {}
        
        self.incManifestSeqNum()
        
        #if 5>self.getManifestSeqNum()>0:
        #    print("Hit manifest seq number of {}".format(self.getManifestSeqNum()))
        #if self.getManifestSeqNum()>=len(order)*9:
        self.filledOrders=sum([order[x].isFulfilled() for x in range(Order.getQty())])
        #print("self.filledOrders:{}".format(self.filledOrders))
        if self.filledOrders!=Order.getQty() and self.getManifestSeqNum()>=3999:
            #self.filledOrders=sum([order[x].isFulfilled() for x in range(Order.getQty())])
            print("Hit manifest seq number limit of {} Ending episode with {} successful deliveries".format(self.getManifestSeqNum(),self.filledOrders))
            #ic(self.filledOrders,self.unfilledOrders,self.other)
            self.done=True 
            #writeLog()
        #self.currentPayload=sum([prodWeight[x] for x in filter(None,drone[self.droneNum][dronePayloadOffset:15]) ])
        #if self.filledOrders/len(orders)>.80:
        #    print("80% of orders completed! ({}) in {} manifest steps".format(self.filledOrders,self.getManifestSeqNum()))
        #    self.done=True 
        if self.filledOrders==Order.getQty():
            print("All orders completed! ({}) in {} manifest steps".format(self.filledOrders,self.getManifestSeqNum()))
            self.done=True 
            writeLog()
        # create observation:
        #observation = [manifestSeqNum,macroScore,droneNum,droneLoc,payloadItems] + list(self.prev_actions)
        whStat=list()
        whStat.append( self.getManifestSeqNum())
        #Get next available drone
        destTime,self.droneNum=min([  (d[x].getDestTime(),ind) for ind,x in enumerate(  range( Drone.getQty() )  ) ])
        whStat.append(self.droneNum)   #Next available drone 
        r,c=d[self.droneNum].getPos()
        closestWh=Calculate.nearestWh(r,c)
        whStat.append(closestWh) #closest wh to next available drone
        radius=30
        for wh in range(Warehouse.getQty()): 
            whStat.append( wh)
            whStat.append(dronesInRadius(wh,radius))
            whStat.append(ordersInStockClose(wh,radius))
            whStat.append(ordersInStockFar(wh,radius) )
            whStat.append(ordersUnfilled(wh) )      
        observation = np.array(whStat)
        #print("Observation:{}   shape:{}".format( observation,observation.shape))
                #Store the prior LUDW command for later use (but only if successful)
        #if self.reward>=0:
        #    priorDroneCmd[self.droneNum] = self.LUDW
        
        #get next drone number for next step
        #self.droneNum=min([d[x].getDestTime() for x in range(Drone.getQty())])
        #print("Step observation:  shape:{} ".format(observation.shape))          
        #print("observation type:{} ".format(type(observation)))
        return observation, self.reward, self.done, info

    def reset(self):
        
        #Item.reset()
        #Order.reset()
        Drone.reset()
        #Warehouse.reset()
        #ProductType.reset()
        Log.reset()

        consumeInputFile2()
        createOrdArray()
       
        #createOrdArray()
        self.resetManifestSeqNum()
        self.total_reward=0
        self.prev_reward = 0
        self.filledOrders = 0
        self.droneNum=0
        self.droneLoc=0
        self.currentPayload=0
        l=list()

        #[ priorDroneCmd.update({x:3}) for x in range(30) ]
        wh=0
        
        self.done = False
        #print("self.getManifestSeqNum:{}".format(self.getManifestSeqNum()))
        # create observation:

        whStat=list()
        whStat.append( self.getManifestSeqNum())
        whStat.append(self.droneNum)
        whStat.append(wh) 
        radius=30
        for wh in range(Warehouse.getQty()): 
            whStat.append( wh)
            whStat.append(dronesInRadius(wh,radius))
            whStat.append(ordersInStockClose(wh,radius))
            whStat.append(ordersInStockFar(wh,radius) )
            whStat.append(ordersUnfilled(wh) )      
        observation = np.array(whStat)
        
        return observation

        
class Data(DroneEnv):
    clock=0
    score=0
    scoreList=list()
    
    def __init__(self):
        super(Data, self).__init__()
        self.name="data parent object"  
        self.clock=99
    def clockTick():
        Data.clock+=1
        return
    def incScore(n):
        Data.score+=n
    def addScoreTup(tup):
        Data.scoreList.append(tup)
    def getScore():
        return Data.score
    def getScoreListLen():
        return len(Data.scoreList)
    
class Algo(DroneEnv):
    def __init__(self):
        super().__init__()
        self.name="Algorithm parent object"
    
class Calculate(Algo):                    ############ A L G O ##################
    def __init__(self):
        super().__init__()
        
              
      
    def deliverLocally(self):
        for wh in range(Warehouse.getQty()): 
            #Each warehouse was designated drones to serve it's local customer orders
            theseDrones=w[wh].getDroneList()
            #t<2 and print("The drones assigned to Wh#{} are: {}".format(wh,theseDrones))
            #t<2 and print("Searching for orders for warehouse:{} ".format(wh))
            for droneNum in theseDrones:
                #t<2 and print("   Wh#{} Determining load for Drone:{}".format(wh,droneNum))
                if d[droneNum].isAvail():
                    #t<2 and print("   Wh#{} Preparing to load drone#{}...".format(wh,droneNum))
                    r,c=d[droneNum].getPos()
                    excessCapacity=d[droneNum].getExcessCapacity()
                    priorityList=w[wh].getLocalPriorityList()
                    if len(priorityList)==0:
                        #print("\t\t\tWh#{} Nothing left to load for drone:{}".format(wh,droneNum))
                        break
                    minimumWeightInList=w[wh].getPriorityListMinWeight()
                    #make sure an option is available, if not, proceed to next
                    endOfOrders=False
                    #print("ExcessCap:{}  minWeightinList:{}".format(excessCapacity,minimumWeightInList))
                    while  excessCapacity >= minimumWeightInList and not endOfOrders:   
                        allowIntermodal=False
                        orderIndex=w[wh].popNextOrder(excessCapacity,allowIntermodal)
                        if isinstance(orderIndex,bool) and orderIndex==False:   #False indicates no valid orders to load
                            endOfOrders=True
                        else:
                            #order[orderIndex].showStatus()
                            #print("\tWh#{} Loaded order {} onto drone:{}".format(wh,orderIndex,droneNum))
                            weight=order[orderIndex].getWeight()
                            itemIdx=order[orderIndex].getAssignedItem()
                            result=d[droneNum].load(orderIndex,wh,order[orderIndex].getProdNum(),1,itemIdx,weight)

                            excessCapacity=d[droneNum].getExcessCapacity()
                            #print("\tWh#{} Drone: {}  remaining capacity: {}".format(wh,droneNum,excessCapacity))
                            priorityList=w[wh].getPriorityList()
                            if len(priorityList)==0:
                                break
                            minimumWeightInList=w[wh].getPriorityListMinWeight()

                    #print("Drone: {} is loaded with {} boxes ".format(droneNum,d[droneNum].getNumItems()))
                    r,c=d[droneNum].getDest()
                    if d[droneNum].getNumItems()>0:
                        DEBUG and print("Wh#{} Drone #{} has {} boxes Next stop:{},{} at time: {}"\
                          .format(wh,droneNum,d[droneNum].getNumItems(),r,c,d[droneNum].getDestTime()))
        #raise SystemExit("Stop right there!")   
    def getImMinWeight(imList):
        minWeight=maxLoad
        for tup in imList:
            #(closestWh,orderIndex,itemIndex)
            _,_,ii=tup
            weight=item[ii].getWeight()
            if weight<minWeight:
                minWeight=weight
        return minWeight
    def selectOrder(imList,excessCapacity):
        selectionLessThanEC=False
        for index,tup in enumerate(imList):
            #(closestWh,orderIndex,itemIndex)
            _,oi,ii=tup
            weight=item[ii].getWeight()
            if weight<excessCapacity:
                selectionLessThanEC=oi
                break
        return selectionLessThanEC
    
    def getAllOrdersForWh(wh):
        orderList=list()
        wr,wc=w[wh].getPos()
        for i in range(Order.getQty()):
            if order[i].getWh()==wh:
                r,c=order[i].getPos()
                dist=Calculate.dist( (r,c),(wr,wc) )
                orderList.append( (i,dist)   )
        #Now sort the generated list of tuples by distance
        orderList.sort(reverse=False,key = lambda x: x[1])
        return orderList
    def subScores():   #subScore is the maxmimum score for this item to be completed. (intermodal dist+ local dist)
        for orderIndex in range(Order.getQty()):
            subScore=0
            imDist,whDist= order[orderIndex].getDistances()
            minTimeToComplete=imDist+whDist
            #if there was an intermodal transfer required, add 2 time units for the load/unload
            if imDist>0:
                subScore=2
            subScore+=imDist+whDist+2 #the +2 is for local warehouse load/delivery unload
            order[orderIndex].setSubScore( subScore )
    def maxScores():   #MaxScore is the maxmimum score for the whole orig order to be completed(sum of subscores)
        for orderIndex in range(Order.getQty()):
            origOrder=order[orderIndex].getOrderNum()
            minTimeToComplete=0
            for i in range(Order.getQty()):
                if order[i].getOrderNum()==origOrder:
                    minTimeToComplete+=order[i].getSubScore()
            maxScore=((deadline-minTimeToComplete)/deadline)*100
            order[orderIndex].setMaxScore( maxScore )
    def maxScores0():   #MaxScore is the maxmimum score for the whole orig order to be completed(sum of subscores)
        for orderIndex in range(Order.getQty()):
            origOrder=order[orderIndex].getOrderNum()
            minTimeToComplete=0
            for i in range(Order.getQty()):
                if order[i].getOrderNum()==origOrder:
                    imDist,whDist= order[i].getDistances()
                    #print("{}  {}".format(i,order[i].getDistances()))
                    minTimeToComplete+=imDist+whDist
            maxScore=(deadline-minTimeToComplete)/deadline
            order[orderIndex].setMaxScore( maxScore )
    def finalStats():
        finalTime=Calculate.getCurrentTime()
        #show total order qty
        print("Total orders possible:{}  originally in stock:{}  ".format(Order.getQty(), origInStockCounter ))
        print("Total intermodal transfers completed:{}"  .format(intermodalXfersCompleted)  )
        #Show order qty delivered
        filled=0
        unfilled=0
        totalScore=0
        #print("OrdIndex fulfilled  remItems  isAssigned  assignedItemIndex turnFulfilled\n"+'-'*50)
        for i in range(Order.getQty()):
            fulfilled, remItems,isAssigned,assignedItemIndex,turnFulfilled=order[i].getEndStatus()
            DEBUG and print(i,fulfilled, remItems,isAssigned,assignedItemIndex,turnFulfilled)
            if fulfilled:
                filled +=1
            else:
                unfilled+=1
        print("Filled:{}   Unfilled:{}".format(filled,unfilled)) 
        self.finalScore(finalTime)
        
    def finalScore(endTime):
        #Calc final score for this sim

        finalScore=0
        for i in range(totalOrders):   #totalOrders came from the reading of the orig input file
            #print("Processing orderNum:{} of {}".format(i,totalOrders))

            lastDeliveryTime=endTime  #initialize to a large num
            foundFulfilled=False
            for oi in range(Order.getQty()):
                if order[oi].getOrderNum()==i and order[oi].getRemItems()==0:   #in the list of orderlines, just look at the ones that match the orderNum
                    foundFulfilled=True
                    #print('FulfilledTime:{} {}'.format( order[oi].getFulfilledTime() ,  isinstance(order[oi].getFulfilledTime(),int) ) )
                    if not isinstance(order[oi].getFulfilledTime(),bool) and order[oi].getFulfilledTime()< lastDeliveryTime:
                        #print('<{}'.format(lastDeliveryTime),end='')
                        lastDeliveryTime=order[oi].getFulfilledTime()
                        #print("Updating last delivery time to:{}".format(lastDeliveryTime))

                        #itemsInThisOrder=order[oi].getItemsInOrder()
            if foundFulfilled:
                thisScore=math.ceil(  (  (endTime-lastDeliveryTime) /endTime)  * 100 )
                finalScore+= thisScore
                DEBUG and print("Order:{} score:{}".format(i,thisScore))
        print("Final score:{} at final time:{}".format(finalScore,endTime))  
        return finalScore
        
    def nearestWh(r,c,whSubList=list()):
        if len(whSubList)==0:
            whSubList=list(range(Warehouse.getQty() ))
        #print("Looking for warehouse closest to: {},{}".format(r,c) )
        maxDist=gridRows+gridCols  #Max possible value
        closestDist=maxDist
        closestWhIndex=-1  
        for index,(wr,wc) in enumerate(whLocs):
            if index not in whSubList:
                continue
            distance=Calculate.dist((r,c),(wr,wc)) 
            if distance<closestDist:
                closestDist=distance
                closestWhIndex=index
        #print("Closest warehouse is:{}".format(closestWhIndex) )
        return closestWhIndex 

    def findAvailProdInWh(pn,wh):
        for i in range(Item.getQty()):
            itemIndex,assigned,prodNum,facType,facIndex=item[i].getStatus3()
            if prodNum==pn and facType=='W' and facIndex==wh and assigned==False:
                break
        return itemIndex
            
    def getStatus3():
        #itemIndex,OrderIndex,prodNum,facType,facIndex
        return (self.__index,self.__assignedToOrder,self.__prodNum,self.__facType,self.__facIndex)
    
    def nearbyWh(r,c,whLocList):
        distToWh=list()
        #If the drone is already at a warehouse location then just return that loc
        for index,(wr,wc) in enumerate(whLocs):
            distToWh.append( dist((r,c),(wr,wc))  )
        #now return the index of the minimal value in the list
        minpos = distToWh.index(min(distToWh))
        #print("The closest warehouse to {},{} is at index {} at a distance of:{}".format(r,c,minpos,min(distToWh)))
        return minpos,min(distToWh)
    def getNewLocation(currR,currC,destR,destC,timeInterval=1):
        adjacent=destR-currR
        opposite=destC-currC
        hyp=math.sqrt(adjacent**2+opposite**2)
        angleRadians=math.atan2(opposite,adjacent)
        #print("Opposite:{}   Adj:{}   Angle:{} Hyp:{}".format(opposite,adjacent,angleRadians,hyp))
        newRow=currR+math.cos(angleRadians)*timeInterval
        newCol=currC+math.sin(angleRadians)*timeInterval
        if hyp<1:
            return destR,destC
        return newRow,newCol
    def decodeLabel(labelString):
        if ('L' in labelString) or ('D' in labelString):
            label=labelString.split()
            droneNum=int(label[0])
            DLW=label[1]
            wh=int(label[2])
            prodNum=int(label[3])
            qty=int(label[4])
            wait=False
            return (droneNum,DLW,wh,prodNum,qty,wait)
        if ('D' in labelString):
            label=labelString.split()
            droneNum=int(label[0])
            DLW=label[1]
            wait=int(label[2])
            wh=False
            prodNum=False
            qty=False
            return (droneNum,DLW,wh,prodNum,qty,wait)
        return (False,False,False,False,False,False)
    
        
    def genLabel(labelTup,labelType):
        DLW=labelType
        if 'L' in  labelType:
            droneNum,DLW,warehouseNum,prodNum,prodQty,_,_,_,weight=labelTup
            label=str(droneNum)+' '+DLW+' '+str(warehouseNum)+' '+str(prodNum)+' '+str(prodQty)
        elif 'D' in  labelType:
            droneNum,DLW,_,prodNum,prodQty,orderIndex,_,itemIndex,weight=labelTup
            #Fetch the original item number using the order index
            orderNum=order[orderIndex].getOrderNum()
            label=str(droneNum)+' '+'D'+' '+str(orderNum)+' '+str(prodNum)+' '+str(prodQty)
        elif 'I' in  labelType:
            #droneNum,DLW,_,prodNum,prodQty,orderIndex,_,itemIndex,weight=labelTup
            droneNum,DLW,warehouseNum,prodNum,prodQty,orderIndex,_,itemIndex,orderWeight=labelTup
            orderNum=order[orderIndex].getOrderNum()
            label=str(droneNum)+' '+'U'+' '+str(warehouseNum)+' '+str(prodNum)+' '+str(prodQty)
        elif 'U' in  labelType:
            #droneNum,DLW,_,prodNum,prodQty,orderIndex,_,itemIndex,weight=labelTup
            droneNum,DLW,warehouseNum,prodNum,prodQty,orderIndex,_,itemIndex,orderWeight=labelTup
            orderNum=order[orderIndex].getOrderNum()
            label=str(droneNum)+' '+'U'+' '+str(warehouseNum)+' '+str(prodNum)+' '+str(prodQty)        
        elif 'W' in labelType:    
            droneNum,DLW,_,_,_,_,wait,_,weight=labelTup
            label=str(droneNum)+' '+DLW+' '+str(wait)
        #print ("Generated label:{} of type:{}".format(label,type(label)))
        return label
    def genOrderList(r,c):   #Unused
        #return a list of orders in the neighborhood with score and dist from r,c and dist from nearest neighbor 
        potentialOrdList=list()
        
        potentialOrdList=Calculate.genOrderList(w[wh].getPos())    
      
    def warehouseWithProdRandom(prodNum,w,item):
        #Identify a random warehouse that has this product. 
        #Question: Will the product still be there when the drone arrives??
        #print("Looking for product number:{} in any warehouse".format(prodNum))
        #tempWHlist=list()
        r = list(range(Item.getQty()))
        random.shuffle(r)
        #print("Quantity of items:   Item.getQty() {}".format(Item.getQty()))
        for i in r:
            #print("item[i].getFacType:{}   item[i].getProdNum():{}".format(item[i].getFacType(),item[i].getProdNum()))
            if item[i].getFacType()=='W' and item[i].getProdNum()==prodNum:    
                return item[i].getWarehouseNum()   
        return False
    def warehousesWithProd(r,c,prodNum,w,item):
        #Identify all warehouses that have this product. 
        #Question: Will the product still be there when the drone arrives??
        
        #print("Looking for product number:{} in warehouses".format(prodNum))
        itemlist=list()
        tempWHlist=list()
        #print("Quantity of items:   Item.getQty() {}".format(Item.getQty()))
        for i in range(Item.getQty()):
            #print("item[i].getFacType:{}   item[i].getProdNum():{}".format(item[i].getFacType(),item[i].getProdNum()))
            if item[i].getFacType()=='W' and item[i].getProdNum()==prodNum:    
                tempWHlist.append(item[i].getWarehouseNum() )  
        return tempWHlist
    
    
    def loadList(r,c,maxLoad,w,item):
        #Find optimal orders to fulfill by calculating the score for the delivery of each product
        DEBUG and print("Looking for product number:{} in warehouses".format(prodNum))
        itemlist=list()
        tempWHlist=list()
        #print("Quantity of items:   Item.getQty() {}".format(Item.getQty()))
        for i in range(Item.getQty()):
            if item[i].getFacType()=='W':    
                 tempWHlist.append(item[i].getWarehouseNum() )  
        #print("Warehouses with the product:{} are:()".format(prodNum,tempWHlist))
        costFnList=list()
        return costFnList
        #for orderNum in range(Order.getQty()):
        #    if order[orderNum].isFulfilled()==True or order[orderNum].msgQueue()==True:
        #        costFnList.append(0)            
    def updateRemItems(ordIndex):                            ################################################
        #Given this single-item order index, find other lines from this same order by using the common orderNum
        if order[ordIndex].getRemItems()==0:
            print("Error 007: Remaining items is already 0. This shouldn't happen.")
            return False
        targetOrderNum=order[ordIndex].getOrderNum()
        linesInThisOrderList=list()
        for i in range(Order.getQty()):
            index,row,col,orderNum,prodNum,remItems= order[i].getStatus()
            if orderNum==targetOrderNum:
                linesInThisOrderList.append(index)
        orderLineQty=len(linesInThisOrderList)
        #Now count the number that are fulfilled
        fulfilledCount=0
        for i in linesInThisOrderList:
            if order[i].isFulfilled():
                fulfilledCount+=1
        remItems=len(linesInThisOrderList)-fulfilledCount
        #Update the order[].setRemItems(n) for each
        for i in linesInThisOrderList:
            order[i].setRemItems(remItems)
        return remItems
  
    def getRandomUnfilledOrder(order):                     
        #tempUnfilledOrderList=list()
        r = list(range(Order.getQty()))
        random.shuffle(r)
        for i in r:
            if order[i].isFulfilled()==False: 
                return order[i].getStatus()              
        return False
    def getRemainingOrders():
        unfilledOrders=0
        unfilledOrdersList=list()
        for i in range(Order.getQty()):
            if order[i].isFulfilled()==False:
                unfilledOrders+=1
                unfilledOrdersList.append(i)
        return unfilledOrders,unfilledOrdersList
            
    def getNearbyUnfilledOrders(warehouseIndex,k):       ####This is the most CPU intensive routine
        wr,wc=w[warehouseIndex].getPos()
        #allOrderlocs is a permanent list of the location of all orders
        X=np.array(allOrderlocs)
        x=np.array([[wr,wc]])
        inds = knn(x, X, k)
        potentialOrderList=list()
        for i in inds:
            #print(order[i].getStatus())
            if order[i].isFulfilled()==False:
                #print('=',end='')
                prodNum=order[i].getProdNum()
                if Calculate.checkStock(warehouseIndex,prodNum)==True:
                    #print("Found the product in warehouse!!")
                    potentialOrderList.append(i)            
        return potentialOrderList
    def getAvgDistNearbyUnfilledOrders(r,c,k):
        #allOrderlocs is a permanent list of the location of all orders
        X=np.array(allOrderlocs)
        x=np.array([[r,c]])
        inds = knn(x, X, k)
        xyList=list()
        nextWhDist=list()
        for i in inds:
            #print(order[i].getStatus())
            if order[i].isFulfilled()==False:
                orderRow,orderCol=order[i].getPos()
                xyList.append( Calculate.distance(orderRow,orderCol,r,c) ) 
                _,whDist=Calculate.nearbyWh(r,c,whLocs)
                nextWhDist.append( whDist )
        return np.mean(xyList),np.mean(nextWhDist)
    
    def orderMetrics(droneRow,DroneCol,wr,wc,potentialOrdList):      
        orderMetricsList=list()
        for i in potentialOrdList:
            index,row,col,orderNum,prodNum,remItems= order[i].getStatus()
            weight=order[i].getWeight()
            #compute dist to wh, nearest neighbor, 
            droneDist=dist((wr,wc),(droneRow,DroneCol) )
            whDist=dist((wr,wc),(row,col) )
            score=((deadline-(Calculate.getCurrentTime()+droneDist+whDist))/deadline) /(remItems)
            #score=((deadline-(Calculate.currentTime()+droneDist+whDist))/deadline) 
            distToNeighbors,neighborAvgDistToWh=Calculate.getAvgDistNearbyUnfilledOrders(row,col,4)
            orderMetricsList.append((i,score,distToNeighbors,neighborAvgDistToWh,weight))
        return orderMetricsList
    
    
    def getRandomAvailableDrone(d):
        r = list(range(Drone.getQty()))
        random.shuffle(r)
        for i in r:
            if d[i].isAvail()==True: 
                return d[i].getStatus()              
        return False
    def distance(r1,c1,r2,c2):
        return math.sqrt(    ( r1-r2   )**2 +  ( c1-c2  )**2     )
    def dist(tup1,tup2):
        (r1,c1)=tup1
        (r2,c2)=tup2
        return math.sqrt(    ( r1-r2   )**2 +  ( c1-c2  )**2     )
    def getCurrentTime():
        return Data.clock
    def setCurrentTime(val):
        Data.clock=val
    def inStock(wh,pn):
        #print("Does warehouse:{} have prodNum:{}?".format(wh,pn))
        for i in range(Item.getQty()):
            itemIndex,prodNum,facType,facIndex,assignedToOrder=item[i].getStatus2()
            #print("Next: {}/{} {}/{} {}/{} ".format(prodNum,pn,facType,'W',facIndex,wh))
            
            if facType=='W' and facIndex==wh and prodNum==pn and assignedToOrder==False :
                DEBUG and print("Product {} is in stock (and available) at wh:{}".format(pn,wh))
                return True
        return False         
    def checkStock(wh,orderId,itemId,pn):
        DEBUG and print("Does warehouse:{} have order:{} which is assigned item:{} (Prod={})?".format(wh,orderId,itemId,pn))
        #for i in range(totalItemsInSim):
        #print("ItemID:{} {}".format(itemId,type(itemId)))
        itemIndex,OrderIndex,prodNum,facType,facIndex=item[itemId].getStatus3()
        #print("Check: {}/{} {}/{} {}/{} {}/{} {}/{}".format(orderIndex,orderId,itemIndex,itemId,facType,'W',facIndex,wh,prodNum,pn))
            
        if facType=='W' and facIndex==wh and itemIndex==itemId and prodNum==pn:
            #print("Product {} is in stock at wh:{}".format(pn,wh))
            return True
        else:
            DEBUG and print("facType=='W'   {}=={}  {}   {}  {}".format (facType,'W',facType=='W',type(facType),type('W')))
            DEBUG and print("facIndex==wh   {}=={}  {}   {}  {}".format (facIndex,wh,facIndex==wh,type(facIndex),type(wh)))
            DEBUG and print("itemIndex==itemId   {}=={}  {}   {}  {}".format (itemIndex,itemId,itemIndex==itemId,type(itemIndex),type(itemId)))
            DEBUG and print("prodNum==pn   {}=={}  {}   {}  {}".format (prodNum,pn,prodNum==pn,type(prodNum),type(pn)))
        return False 
    def checkItem(wh,orderId,itemId):
        print("Order:{} Does the item #{} show it is located in this warehouse({})?".format(orderId,itemId,wh))
        #for i in range(totalItemsInSim):
        
        itemIndex,OrderIndex,prodNum,facType,facIndex=item[itemId].getStatus3()
        DEBUG and print("Check: {}/{} {}/{} {}/{} {}/{} ".format(orderIndex,orderId,itemIndex,itemId,facType,'W',facIndex,wh))
            
        if facType=='W' and facIndex==wh and itemIndex==itemIdx:
            #print("Product {} is in stock at wh:{}".format(pn,wh))
            return True
        else:
            DEBUG and print("facType=='W'   {}=={}  {}   {}  {}".format (facType,'W',facType=='W',type(facType),type('W')))
            DEBUG and print("facIndex==wh   {}=={}  {}   {}  {}".format (facIndex,wh,facIndex==wh,type(facIndex),type(wh)))
            DEBUG and print("itemIndex==itemIdx   {}=={}  {}   {}  {}".format (itemIndex,itemId,itemIndex==itemId,type(itemIndex),type(itemId)))
        return False 
    
    def xfer2Drone(itemIndex,droneNum):    
        #are item and drone in the same location??

        result=item[itemIndex].droneLoad(droneNum)
        return result

    def showLog():
        for i in range(len(log)):
            print(log[i].getLine())
        return
    
    
class Log(Data):    ########## Logfile to store commands  #######
    counter=-1
    def __init__(self,logString):
        super().__init__()
        Log.counter += 1
        self.__logString=logString
    def reset():
        Log.counter=-1
    def getCount():
        return Log.counter
    def getQty():
        return Log.counter
    def getLine(self):
        return self.__logString
    def show(self):
        print(self.__logString)
    def showAll():
        for i in range(Log.getQty()):
            log[i].show()
    def showAllForDrone(dn):
        for i in range(Log.getQty()):
            line=log[i].getLine().split()
            if int(line[0])==dn:
                print(line)
            
        
    
class Warehouse(Data):              ####  Warehouse ####
    counter=0
    def __init__(self,warehouseNum,row,col):
        self.__index=Warehouse.counter
        Warehouse.counter += 1
        super().__init__()
        #self.counter += 1
        self.__warehouseNum=warehouseNum
        self.__intermodalList=list()
        self.__row=row
        self.__col=col
        self.__droneList=list()
        self.__priorityList=list()
    def reset():
        Warehouse.counter=0
    def generatePriorityList(self):
        self.__priorityList=list()
        #create list of all orders for this wh with associated metrics tuple
        #Priority list fields: index,maxscore,weight,intermodal
        for i in range(Order.getQty()):
            if order[i].getWh()==self.__warehouseNum and not order[i].isFulfilled() and not order[i].getDeliveryInProcess()==True:
                #print("Orders: {}".format(i))
                ms=order[i].getMaxScore()
                self.__priorityList.append( (i,ms,order[i].getWeight(),order[i].isIntermodal()) )
        self.__priorityList.sort(reverse=True,key = lambda x: x[1])
        #print("Priority:{}".format(self.__priorityList))
        #return self.__priorityList
    def showPriorityList(self):
        print("orderIndex,maxscore,weight,intermodal True/False")
        print("Warehouse:{} Priority List:{}".format(self.__warehouseNum,self.__priorityList))
    def getPriorityList(self):
        return self.__priorityList
    def getLocalPriorityList(self):
        localList=list()
        for i in range(len(self.__priorityList)):
            oi,ms,weight,im=self.__priorityList[i]
            if not order[oi].isIm():
                localList.append(self.__priorityList[i])
        return localList
        #return self.__priorityList
    def getPriorityListMinWeight(self):
        #Find minimum weight in prioritized list that is not intermodal
        PriorityListNoIm = [item for item in self.__priorityList if item[3] == False ]
        if len(PriorityListNoIm)==0:
            return False
        _,_,minimumWeightInList,isIntermodal = min(PriorityListNoIm, key=lambda tup: tup[2])
        return minimumWeightInList
    def popNextOrder(self,maxWeight,allowIntermodal):
        #if allowIntermodal is false, don't include orders with an itemNum type tuple
        #Priority list fields: index,maxscore,weight,intermodal
        #print("popnextOrder:   AllowIntermodal:{}".format(allowIntermodal))
        for i in range(len(self.__priorityList)):   
            if self.__priorityList[i][2]<=maxWeight:
                #print("Priority list item:{} is < maxweight:{}".format(i,maxWeight))
                #print(self.__priorityList[i][3], allowIntermodal)
                if (self.__priorityList[i][3]==False or allowIntermodal==True) :
                    ordIndex=self.__priorityList[i][0]
                    #print("ordIndex:{}   delivery in process:{}".format(ordIndex,order[ordIndex].getDeliveryInProcess()))
                    if order[ordIndex].getDeliveryInProcess()!=True:
                        DEBUG and print("Length of self.__priorityList: {}  i={}".format(len(self.__priorityList),i))
                        self.__priorityList.pop(i)
                        DEBUG and print("returning order index :{}".format(ordIndex))
                        return ordIndex
        return False
    def assignDrone(self,droneNum):
        self.__droneList.append(droneNum)
    def getDroneList(self):
        return self.__droneList
    def getStatus(self):
        return self.__warehouseNum,self.__row,self.__col
    def getCount(self):
        return self.counter
    def getQty():
        return Warehouse.counter
    def reset():
        Warehouse.counter=0
    def getPos(self):
        return self.__row,self.__col                           
    def addToIntermodalList(self,tup):
        self.__intermodalList.append(tup)
    def removeFromIntermodalList(self,target_oi,target_ii):
        #print("Request for removal of ord:{} item:{} from IM list on Wh:{}".format(target_oi,target_ii,self.__warehouseNum))
        for i in range(len(self.__intermodalList)):
            sourceWh,oi,ii= self.__intermodalList[i]
            if isinstance(target_ii,tuple):
                #print("Converting tuple: {}".format(target_ii))
                target_ii,donorWh=target_ii
            if oi==target_oi and ii==target_ii:
                self.__intermodalList.pop(i)
                #print("Success!")
                return True
        #print("Failed.")
        return False
        
    def getIntermodalList(self,wh=-1):
        #(closestWh,orderIndex,itemIndex)
        #By default (wh=-1) return the whole list
        # otherwise only return the tuples from the warehouses in the provided list
        ## new feature: do not include orders that are currently being flown intermodally
        newList=list()
        if wh==-1:
            for tup in self.__intermodalList:
                closestWh,orderIndex,itemIndex=tup
                if order[orderIndex].getIntermodal()!=True:
                    newList.append( (closestWh,orderIndex,itemIndex)    )
            return newList
        else:
            #print("searching for Wh={}".format(wh))
            imList = [tup for tup in self.__intermodalList if tup[0] == wh]
            for tup in imList:
                closestWh,orderIndex,itemIndex=tup
                if order[orderIndex].getIntermodal()!=True:
                    newList.append( (closestWh,orderIndex,itemIndex)    )
            return newList
            
    def getInventory(self,pn):
        #print("Item is type {}".format(itemObj))
        #itemQuantity=itemObj[0].getQty()
        #print("itemQuantity:{}".format(itemQuantity))
        itemCount=0
        for i in range(Item.getQty()):
            if item[i].getWarehouse()==('W',self.__warehouseNum) and item[i].getProdNum==pn and item[i].isAssigned==False:
                itemCount+=1
        return itemCount
    def loadInitialProduct(self,p,productNum,qty):
        p[productNum].addItem(qty,'W',self.__warehouseNum)


class ProductType(Data):               ############## ProductType Object ############
    counter=0
    def __init__(self,prodNum,weight):
        super().__init__()
        self.counter += 1
        self.__prodNum=prodNum
        self.__weight=weight
        self.__qty=0
        self.__itemList=list()
    def reset():
        ProductType.counter=0
    def getQty():
        return ProductType.counter
    def getWeight(self):
        return self.__weight
    def getStatus(self):
        return (self.__prodNum,self.__weight)
    def addItem(self,qty,facilityType,facilityNum):
        #print("Adding item: {} with qty:{} at {}{}".format(self.__prodNum,qty,facilityType,facilityNum))
        for ii in qty:
            #print('.',end='')
            self.__itemList.append(self.__qty)
            self.__qty+=1
            #print("self.__itemList:{}".format(self.__itemList))
            
            #self.__item[self.__itemList[self.__qty]].load(self.__prodNum,self.__weight,(facilityType,facilityNum))
        return
        
        
class Item():              ############## Item Object ############
    counter=0
    def __init__(self,prodNum,facType,facIndex,weight):
        #super().__init__(prodNum,weight)
        self.__index=Item.counter
        Item.counter += 1
        self.__prodNum=prodNum
        self.__weight=weight
        self.__facType=facType   #indicating D,W or C  for Drone/Warehouse/Cust
        self.__facIndex=facIndex  #index of container D/W/C           
        self.__deliveryTime=-1
        self.__assignedToOrder=False
        #print("Instantiated new item object")
    def setLoc(self,facType,facIndex):
        self.__facType,self.__facIndex=facType,facIndex
    def getQty():
        return Item.counter
    def reset():
        Item.counter=0
        
    def getWeight(self):
        return self.__weight
    def getWarehouse(self):
        return self.__facType,self.__facIndex
    def getWarehouseNum(self):
        return self.__facIndex
    def getFacType(self):
        return self.__facType    
    def getProdNum(self):
        return self.__prodNum
    def load(self,facType,facIndex):
        #self.counter += 1
        #self.__prodNum=num
        #self.__weight=weight
        self.__facType=facType   #indicating D,W or C  for Drone/Warehouse/Cust
        self.__facIndex=facIndex  #index of container D/W/C   
        #DEBUG and print("Instantiated: {} {} {}{}".format(prodNum,weight,facType,facIndex))
    def droneLoad(self,droneNum):
        self.__facType='D'  
        self.__facIndex=droneNum
        return True
    def setCustDelivery(self,custLoc):  
        self.__facType='C'  
        self.__facIndex=custLoc
        self.__deliveryTime=Calculate.getCurrentTime()
    def assignToOrder(self,ordNum):
        self.__assignedToOrder=ordNum
    def isAssigned(self):
        return self.__assignedToOrder        
    def getStatus(self):
        return self.__index,self.__prodNum,self.__facType,self.__facIndex
    def getStatus2(self):
        return self.__index,self.__prodNum,self.__facType,self.__facIndex,self.__assignedToOrder

    def getStatus3(self):
        #itemIndex,OrderIndex,prodNum,facType,facIndex
        return (self.__index,self.__assignedToOrder,self.__prodNum,self.__facType,self.__facIndex)
    def showStatus(self):
        print("Item:{}\nProdNum:{}\nLoc:{}{}".format(self.__index,self.__prodNum,self.__facType,self.__facIndex))
        print("Assigned to order:{}".format(self.__assignedToOrder))
        print("Delivery Time:{}".format(self.__deliveryTime))
        print("Weight:{}".format(self.__weight))
        
class Drone(Data):                ###############   Drone ########
    counter=0
    def __init__(self,row,col,maxLoad):
        super().__init__()
        self.__index=Drone.counter
        Drone.counter += 1
        self.__maxLoad=maxLoad
        self.__enRoute=False
        self.__deliveringBoxIndex=False
        self.__destRow=row
        self.__destCol=col
        self.__destTime=0
        self.__boxes=list()
        self.__labels=list()
        self.__payload=list()
        self.__row=row
        self.__col=col
        self.__assignedToWh=False
        self.__imFlight=False
    def reset():
        Drone.counter=0
    def empty(self):
        self.__enRoute=False
        self.__deliveringBoxIndex=False
        self.__destRow=False
        self.__destCol=False
        self.__destTime=False
        self.__boxes=list()
        self.__labels=list()
        self.__payload=list()
    def removeImBoxes(self):
        #remove any boxes marked Intermodal transfer
        for i in range(len(self.__boxes)-1,-1,-1):
            if self.__boxes[i][1]=='I':
                self.__boxes.pop(i)
    def isAssignedToWh(self):
        return self.__assignedToWh
    def setAssignedToWh(self,val):
        self.__assignedToWh=val
    def getNumItems(self):
        return len(self.__boxes)
    def setImFlight(self,val):
        self.__imFlight=val
    def getImFlight(self):
        return self.__imFlight
    def fly2Cust(self):
        if len(self.__boxes)==0:
            return False
        closestIndex=-1
        closestDist=9999
        closestrc=(-1,-1)
        #find the closest order delivery site for the onboard packages
        for i in range(len(self.__boxes)):
            labelTup=self.__boxes[i]
            droneIndex,DLW,wh,prodNum,qty,orderIndex,wait,itemIndex,weight=labelTup
            cr,cc=order[orderIndex].getPos()
            dist=Calculate.distance(self.__row,self.__col,cr,cc)
            if dist <closestDist:
                closestDist=dist
                closestIndex=i
                closestrc=(cr,cc)
        #Now set the Destination and arrival time and enroute params
        self.deliveringBoxIndex(closestIndex)
        self.__enRoute=True
        self.__destRow,self.__destCol=closestrc
        dist=math.ceil( Calculate.distance(self.__row,self.__col,self.__destRow,self.__destCol) )
        DEBUG and print("Drone #{} Now flying to {},{} for order:{} / item{}".format(self.__index,self.__destRow,self.__destCol,orderIndex,itemIndex))
        DEBUG and print("Hypot:{} Ceiling dist/time:{}".format(Calculate.distance(self.__row,self.__col,self.__destRow,self.__destCol),dist) )

        currentTime=Calculate.getCurrentTime()
        self.__destTime=currentTime+dist +1
        
    def xfer2Cust(self):                                                ########## Xfer2Cust  ##############
        #Adjust r,c to exact vals as there may have been accumulated rounding error inflight
        self.__row,self.__col==round(self.__row),round(self.__col)
        #find all boxes that should be delivered to this grid location
        DEBUG and print("Transferring box(es) to cust at {},{} ".format( self.__row,self.__col))
        listOfBoxesToRemove=list()
        tempBoxList=self.__boxes
        for i in range(len(tempBoxList)):
            labelTup=tempBoxList[i]
            droneNum, LDW,_,prodNum,prodQty,orderIndex,_,itemIndex,weight=labelTup
            cr,cc=order[orderIndex].getPos()
            if ( self.__row,self.__col )==(cr,cc):
                DEBUG and print("Order:{} matches this location {},{} so delivering it here.".format(orderIndex,cr,cc))
                #unload this box
                listOfBoxesToRemove.insert(0,orderIndex)
                
                newBoxList = [x for x in self.__boxes if x[5] != orderIndex ]
                self.__boxes=newBoxList
                DEBUG and print("Removing box order {} from \n=>boxlist:{} \n==>now:{}".format(orderIndex,tempBoxList,self.__boxes))
                order[orderIndex].setFulfilled(Calculate.getCurrentTime(),itemIndex)
                assWh=order[orderIndex].getWh()
                w[assWh].generatePriorityList()
                item[itemIndex].setCustDelivery( (cr,cc) ) #Update this item with its final details
                Data.incScore(1)   
                
                labelTup=(droneNum, 'D',False,prodNum,qty,orderIndex,False,itemIndex,_)
                log.append(Log(Calculate.genLabel(labelTup,'D')))
                
                
                Calculate.updateRemItems(orderIndex)                         #*********************************
                
                
                
                
                
        #listOfBoxesToRemove.sort(reverse=True) #pop items from the end of the list to the front
        #for oi in listOfBoxesToRemove: 
        #    print("Removing box with order {} from listOfBoxesToRemove:{}".format(oi,listOfBoxesToRemove))
            #newBoxList = [x for x in self.__boxes if x[5] == oi ] #remove this box from the list
        #self.__boxes=newBoxList
        #print("Remaining boxes:")
        #self.showBoxes()
        ###
        ###Note:after deliveries the priority list of the warehouse should be recalced################
        #####
        
        #if there are more boxes on board, set the flight path to the next closest
        if len(self.__boxes)>0:
            DEBUG and print("Drone:{} is NOT empty. Remaining:{}".format(self.__index,self.__boxes))
            self.fly2Cust()
        else:
            #Drone is empty. Clear values so next round it can be reloaded
            DEBUG and print("Drone:{} is empty {}".format(self.__index,'*'*50))
            self.empty()

    def deliveringBoxIndex(self,boxIndex):  
        self.__deliveringBoxIndex=boxIndex
    def pushBox(self,label):
        self.__boxes.append(  (label) )
        return 
    def swapLabelforDelivery(self,boxIndex):
        labelTup=self.__boxes[boxIndex] 
        labelList=list(labelTup)
        labelList[1]='D'
        labelTup=tuple(labelList)
        self.__boxes[boxIndex]=(labelTup)

    def getBoxes(self):
        boxList=list()
        for b in self.__boxes:
            boxList.append(b)
        return boxList
    def showBoxes(self):
        print("index,LDW,warehouseNum,prodNum,prodQty,orderIndex,wait,itemIndex,orderWeight")
        for b in self.__boxes:
            print("{}  ".format(b),end='')
        print("")
        return 
    def setDest(self,r,c):
        self.__destRow,self.__destCol=r,c
    def getDest(self):
        return self.__destRow,self.__destCol
    def getDestTime(self):
        return self.__destTime
    def setDestTime(self,val):
        self.__destTime=val
    def getExcessCapacity(self):
        currentPayload = sum(tup[8] for tup in self.__boxes)
        return self.__maxLoad-currentPayload
    def getPos(self):
        return self.__row,self.__col
    def setPos(self,r,c):
        self.__row,self.__col=r,c
    def updateLocation(self,newR,newC):
        self.__row,self.__col=newR,newC
    def setEnRoute(self,val):
        self.__enRoute=val
    def isEnRoute(self):
        return (self.__enRoute)
    def isAvail(self):
        return not(self.__enRoute)
    def setAvail(self,val):
        self.__enRoute= not val
    def getStatus(self):
        return self.__index,self.__enRoute,self.__destRow,self.__destCol,self.__destTime
    def showStatus(self):
        print ("Drone #: {}".format(self.__index) )
        print ("En route:{}".format(self.__enRoute) )
        print ("Row:{} Col:{}".format(self.__row,self.__col) )
        print ("Dest Row:{} DestCol:{}".format(self.__destRow,self.__destCol) )
        print ("Dest Time:{}".format(self.__destTime) )
        print ("Assigned to warehouse:{}".format(self.__assignedToWh))
        print ("Intermodal:{}".format(self.__imFlight))
        self.showBoxes()
    def getQty():
        return Drone.counter
    def reset():
        Drone.counter=0
    def load(self,orderIndex,warehouseNum,prodNum,prodQty,itemIndex,orderWeight,intermodal=False):

        order[orderIndex].setDeliveryInProcess(True)
        dr,dc=w[warehouseNum].getPos()
        self.setDest(dr,dc)
        #print ("D#{} Dest Row:{} Dest Col:{} IM:{}".format(self.__index,self.__destRow,self.__destCol,intermodal) )
        dist=math.ceil( Calculate.distance(self.__row,self.__col,self.__destRow,self.__destCol) )
        
        currentTime=Calculate.getCurrentTime()
        self.__destTime=currentTime+dist+1
        self.__enRoute=True  
        DEBUG and print ("D#{} Dest Row:{} Dest Col:{} DestTime:{} IM:{}".format(self.__index,self.__destRow,self.__destCol,self.__destTime,intermodal) )
        if intermodal:
            labelTup=(self.__index, 'LI',warehouseNum,prodNum,prodQty,orderIndex,False,itemIndex,orderWeight)
            #   log.append(Log(Calculate.genLabel(labelTup,'I')))
        else:
            labelTup=(self.__index, 'L',warehouseNum,prodNum,prodQty,orderIndex,False,itemIndex,orderWeight)
            #    log.append(Log(Calculate.genLabel(labelTup,'L')))
        self.pushBox(labelTup)
        return True
    def hasArrived(self):
        #print("{},{} {},{}".format(self.__row,self.__col,self.__destRow,self.__destCol))
        #if ( self.__destTime==Calculate.currentTime() ) and ( (round(self.__row),round(self.__col))==((self.__destRow,self.__destCol))  ):

        if ( self.__destTime==Calculate.getCurrentTime() ) :
            #Adjust r,c to exact vals as there may have been accumulated error inflight
            distanceError=Calculate.dist( (self.__row,self.__col), (self.__destRow,self.__destCol) )
            if distanceError>(1.5):
                print("Error 006: expected location is outside anticipated rounding error.")
                print("            distance offset={}".format(distanceError))  
                print("            Dest Time: {}   Current Time: {} ".format(self.__destTime,Calculate.getCurrentTime()))
            self.__row,self.__col==self.__destRow,self.__destCol
            #Is the drone at a warehouse location?
            if  (  self.__row,self.__col  )  in whDict:
                return (True,'W')
            #Is the drone at a customer location for one of the onboard boxes?
            DEBUG and print("Boxes on board:{}".format(self.__boxes))
            for tup in self.__boxes:
                _,_,_,_,_,orderIndex,_,itemIndex,weight=tup
                cr,cc=order[orderIndex].getPos()
                DEBUG and print("Order:{} has a delivery location of:{},{}".format(orderIndex,cr,cc))
                if (  round(self.__row),round(self.__col)  )==(cr,cc):
                    DEBUG and print("The drones current pos is: {},{} so it has arrived.".format(round(self.__row),round(self.__col)))
                    return (True,'C')
            #We ended up where we thought we wanted to be, but this is not
            #  a warehouse location or an address for an onboard box
            print("Error 005: Drone:{} is confused while at {},{}".format(self.__index,self.__row,self.__col))
            print("( self.__destTime==Calculate.getCurrentTime() ) {}".format(( self.__destTime==Calculate.getCurrentTime() ) ))
            print( " (round(self.__row),round(self.__col))==((self.__destRow,self.__destCol))",end='')
            print(  (round(self.__row),round(self.__col)==((self.__destRow,self.__destCol))) )
            
            #self.showStatus()
            
        return (False,False)
        
    
class Order(Data):            ########## Order ########
    counter=0
    def __init__(self,orderNum,row,col,prodNum,remItems,weight): 
        self.__index=Order.counter
        Order.counter+=1
        self.__row=row
        self.__col=col
        self.__orderNum=orderNum
        self.__prodNum=prodNum
        self.__isAssigned=False
        self.__assignedItemIndex=-1
        self.__fulfilled=False
        self.__loaded=False
        self.__turnFulfilled=False
        self.__itemDeliveredIndex=False
        self.__itemsInThisOrder=remItems
        self.__remItems=remItems
        self.__msgQueue=False
        self.__weight=weight
        self.__assignedWarehouse=False  #Closest wh to customer
        self.__subScore=False
        self.__maxScore=False
        self.__imInProcess=False  #Intermodal
        self.__deliveryInProcess=False 
    def reset():
        Order.counter=0
        self.__index=Order.counter
    def getItemsInOrder(self):
        return self.__itemsInThisOrder
    def setIntermodal(self,val):
        self.__imInProcess=val
    def getIntermodal(self):
        return self.__imInProcess
    def isIm(self):
        if isinstance(self.__assignedItemIndex,tuple):
            return True
        return False
    def setDeliveryInProcess(self,DIPval):
        self.__deliveryInProcess=DIPval
    def getDeliveryInProcess(self):
        return self.__deliveryInProcess
    def getMetrics(self):
        #(intermodal dist, WhDist,remaining items,weight,maxScore)
        if self.isAssigned():
            imDist=0
            wr,wc=w[self.__assignedWarehouse].getPos()
            whDist=Calculate.dist( (self.__row,self.__col), (wr,wc))
            if isinstance(self.__assignedItemIndex,tuple):
                itemIndex,imWh=self.__assignedItemIndex
                imRow,imCol=w[imWh].getPos()
                imDist=Calculate.dist( (imRow,imCol), (wr,wc))  
                maxScore=0
                #maxScore=Calculate.orderMaxScore(self.__index)

            return (imDist,whDist,self.__remItems,self.__weight,maxScore)
        return (False,False,self.__remItems,self.__weight,False)
    def getDistances(self):
        if self.isAssigned():
            imDist=0
            wr,wc=w[self.__assignedWarehouse].getPos()
            whDist=Calculate.dist( (self.__row,self.__col), (wr,wc))
            if isinstance(self.__assignedItemIndex,tuple):
                itemIndex,imWh=self.__assignedItemIndex
                imRow,imCol=w[imWh].getPos()
                imDist=Calculate.dist( (imRow,imCol), (wr,wc))  
            return (imDist,whDist)
        raise SystemExit("Stop right here to evaluate!") 

    def getMaxScore(self):
        return self.__maxScore
    def setMaxScore(self,n):
        self.__maxScore=n
        return 
    def getSubScore(self):
        return self.__subScore
    def setSubScore(self,n):
        self.__subScore=n
        return 
    def getQty():
        return Order.counter
    def reset():
        Order.counter=0
    def isAssigned(self):
        return self.__isAssigned
    def setAssignedItem(self,itemIndex):
        self.__isAssigned=True
        self.__assignedItemIndex=itemIndex
    def isIntermodal(self):
        if isinstance(self.__assignedItemIndex,tuple):
            return True
        else:
            return False
    def getAssignedItem(self):
        return self.__assignedItemIndex
    def setWh(self,wh):
        self.__assignedWarehouse=wh
    def getWh(self):
        return self.__assignedWarehouse        
    def getPos(self):
        return self.__row,self.__col
    def getProdNum(self):
        return self.__prodNum
    def getWeight(self):
        return p[self.__prodNum].getWeight()
    def getOrderNum(self):
        return self.__orderNum
    def setQueue(self,droneNum):
        self.__msgQueue=droneNum
        return 
    def getQueue(self):
        return self.__msgQueue
    def setRemItems(self,remItems):
        self.__remItems=remItems
        return 
    def getRemItems(self):
        return self.__remItems

    def isLoaded(self):
        return self.__loaded
    def setLoaded(self,val):
        self.__loaded=val
    def isFulfilled(self):
        return self.__fulfilled
    def setFulfilled(self,t,itemDeliveredIndex):
        self.__turnFulfilled=t
        self.__fulfilled=True
        self.__itemDeliveredIndex==itemDeliveredIndex
    def getFulfilledTime(self):
        return self.__turnFulfilled
    def getStatus(self):
        return self.__index,self.__row,self.__col,self.__orderNum,self.__prodNum,self.__remItems
    def getEndStatus(self):
        return self.__fulfilled, self.__remItems,self.__isAssigned,self.__assignedItemIndex,self.__turnFulfilled
    def showStatus(self):
        print("Order: {}\nLoc:{},{}".format(self.__index,self.__row,self.__col))
        print("Orig OrderNum: {}\nProdNum:{}  Weight:{}".format(self.__orderNum,self.__prodNum,self.__weight))
        print("Is Assigned:{}   AssignedItem:{}".format(self.__isAssigned,self.__assignedItemIndex))
        print("Warehouse:{}\nFulFilledAt:{}".format(self.__assignedWarehouse ,self.__turnFulfilled ))
        print("RemItems: {}\nFulfilled:{}".format(self.__remItems,self.__fulfilled))
        print("subScore: {}   maxScore:{}".format(self.__subScore,self.__maxScore))
        print("Delivery in process: {}".format(self.__deliveryInProcess))
class Sim(Algo):
    counter=0
    def __init__(self):
        super().__init__()
        self.counter += 1
        self.__rows=False
        self.__cols=False
        self.__droneQty=False
        self.__deadline=False
        self.__droneMaxPayload=False
    def initializeParams(self,rows,cols,droneQty,deadline,maxLoad):
        self.__rows=rows
        self.__cols=cols
        self.__droneQty=droneQty
        self.__deadline=deadline
        self.__droneMaxPayload=maxLoad        
    def getStatus(self):
        print("Grid:{}x{}".format(self.__rows,self.__cols))
        print("Drone Qty:{}   Max Payload:{}".format(self.__droneQty,self.__droneMaxPayload))
        print("Deadline:{}".format(self.__deadline))
        return

# %%
    wh1=0
    wh2=1
    cluster=ordArray[:, [0,1,2,3,4,5]]
    clusterArray=cluster[( (cluster[:,1]) **2+ (cc-cluster[:,2])**2).argsort()  ] 
    i=0
    while ec>2 and i<len(clusterArray):
        if clusterArray[i][3]<=ec and clusterArray[i][4]==0 and clusterArray[i][5]==0:
            ec=ec-order[i].getWeight()
            loadManifest.append(i)
            #unloadManifest.append(i)
            #mark as unavailable
            order[i].setLoaded(True)
            ordArray[i][4]=1 
            clusterArray[i][4]=1
        i+=1

# %%
    needyWh=2
    donorWh=1
    orderList=list()
    ec=200
    for i in range(Order.getQty()):
        if ec<2:
            break
        if order[i].getWh()!=needyWh or order[i].isFulfilled()==True:
            continue
        itemIndex,wh=order[i].getAssignedItem() 
        if wh!=donorWh or order[i].getWeight()>ec:
            continue
        orderList.append(i)
        ec=ec-order[i].getWeight()
        order[i].showStatus()
    print("OrderList:{}".format(orderList))
# Out:
# Order: 1459
# Loc:138,87
# Orig OrderNum: 192
# ProdNum:54  Weight:55
# Is Assigned:True   AssignedItem:(1619, 1)
# Warehouse:2
# FulFilledAt:False
# RemItems: 7
# Fulfilled:False
# subScore: False   maxScore:False
# Delivery in process: False
# Order: 3691
# Loc:257,81
# Orig OrderNum: 482
# ProdNum:349  Weight:52
# Is Assigned:True   AssignedItem:(2606, 1)
# Warehouse:2
# FulFilledAt:False
# RemItems: 12
# Fulfilled:False
# subScore: False   maxScore:False
# Delivery in process: False
# Order: 4461
# Loc:204,115
# Orig OrderNum: 584
# ProdNum:316  Weight:41
# Is Assigned:True   AssignedItem:(2451, 1)
# Warehouse:2
# FulFilledAt:False
# RemItems: 7
# Fulfilled:False
# subScore: False   maxScore:False
# Delivery in process: False
# Order: 5473
# Loc:230,49
# Orig OrderNum: 714
# ProdNum:349  Weight:52
# Is Assigned:True   AssignedItem:(2605, 1)
# Warehouse:2
# FulFilledAt:False
# RemItems: 9
# Fulfilled:False
# subScore: False   maxScore:False
# Delivery in process: False
# OrderList:[1459, 3691, 4461, 5473]

# %%
Order.getQty()
# Out:
# 0

# %%
env = DroneEnv()

# %%
env.reset()
# Out:
# Warehouse 0
# Warehouse 1
# Warehouse 2
# Warehouse 3
# Warehouse 4
# Warehouse 5
# Warehouse 6
# Warehouse 7
# Warehouse 8
# Warehouse 9
#
#
#
# ordArrayMaster doesnt exist yet. Make a master and a copy
# array([0, 0, 0, 0, 3, 0, 3, 1, 1, 0, 0, 3, 0, 2, 0, 0, 3, 0, 3, 0, 0, 3,
#        0, 4, 0, 0, 3, 2, 5, 0, 0, 3, 0, 6, 0, 0, 3, 2, 7, 0, 0, 3, 0, 8,
#        0, 0, 3, 0, 9, 0, 0, 3, 2])

# %%
w[0].getInventory(2)
# Out:
# 0

# %%
item[0].getProdNum()
# Out:
# 2

# %%
for i in range(Item.getQty()):
    if item[i].getProdNum()==55: 
        print("item:{}  isAssigned:{}".format(i,item[i].isAssigned(), ))
# Out:
# item:3100  isAssigned:1762
# item:3101  isAssigned:5469
# item:3102  isAssigned:43
# item:3103  isAssigned:3344
# item:3104  isAssigned:33
# item:3105  isAssigned:2965
# item:3106  isAssigned:504
# item:3107  isAssigned:4082
# item:3108  isAssigned:9184
# item:3109  isAssigned:2059
# item:3110  isAssigned:1553
# item:3111  isAssigned:7148
# item:3112  isAssigned:2179
# item:3113  isAssigned:False
# item:3114  isAssigned:False
# item:3115  isAssigned:False
# item:3116  isAssigned:False
# item:3117  isAssigned:False

# %%
for i in range(Order.getQty()):
    if order[i].getProdNum()==55: 
        print("order:{}  assigned item:{}  assigned wh:{}".format(i,order[i].getAssignedItem(),order[i].getWh() ))
# Out:
# order:33  assigned item:(3104, 2)  assigned wh:4
# order:43  assigned item:(3102, 2)  assigned wh:3
# order:504  assigned item:(3106, 2)  assigned wh:4
# order:1553  assigned item:(3110, 2)  assigned wh:6
# order:1762  assigned item:(3100, 2)  assigned wh:0
# order:2059  assigned item:(3109, 2)  assigned wh:6
# order:2179  assigned item:(3112, 2)  assigned wh:9
# order:2965  assigned item:(3105, 2)  assigned wh:4
# order:3344  assigned item:(3103, 2)  assigned wh:3
# order:4082  assigned item:(3107, 2)  assigned wh:4
# order:5469  assigned item:(3101, 2)  assigned wh:0
# order:7148  assigned item:(3111, 2)  assigned wh:6
# order:9184  assigned item:(3108, 2)  assigned wh:5

# %%
Warehouse.getQty(),Drone.getQty(),Order.getQty(),Item.getQty()
# Out:
# (10, 30, 9368, 14576)

# %%
Warehouse.getQty(),Drone.getQty(),Order.getQty(),Item.getQty()
# Out:
# (10, 30, 9368, 14576)

# %%
ordArray.shape
# Out:
# (9368, 106)

# %%
import copy
print(type(order))
#print(order)
#ordMaster=copy.deepcopy(order)
#print(order)
#print(type(ordMaster))
#print(ordMaster)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [3], line 2
#       1 import copy
# ----> 2 print(type(order))
#
# NameError: name 'order' is not defined

# %%
#print(ordMaster)

# %% [raw]
# type(Order)

# %%
############################## Main ##################################
env = DroneEnv()
#createOrdArray()

env.reset()

l=Log('init')
log=list()
#calc=Calculate()
item=list()

locations={}
Order.reset()
Item.reset()
Drone.reset()

#consumeInputFile2()

#Calc min time to deliver this item of the order
Calculate.subScores()
#Calculate max score for each order. Max score is based onthe minimum time to complete the
#  full order (all items in the order must be delivered to score)
Calculate.maxScores()

#createOrdArray()


print("Time deadline: {}".format(deadline))
# Out:
# ---------------------------------------------------------------------------
# UnsupportedError                          Traceback (most recent call last)
# Cell In [7], line 5
#       2 env = DroneEnv()
#       3 #createOrdArray()
# ----> 5 env.reset()
#       7 l=Log('init')
#       8 log=list()
#
# Cell In [6], line 739, in DroneEnv.reset(self)
#     735 ProductType.reset()
#     736 Log.reset()
# --> 739 consumeInputFile2()
#     740 createOrdArray()
#     742 #createOrdArray()
#
# File ~\anaconda3\lib\site-packages\numba\core\dispatcher.py:471, in _DispatcherBase._compile_for_args(self, *args, **kws)
#     468     error_rewrite(e, 'typing')
#     469 except errors.UnsupportedError as e:
#     470     # Something unsupported is present in the user code, add help info
# --> 471     error_rewrite(e, 'unsupported_error')
#     472 except (errors.NotDefinedError, errors.RedefinedError,
#     473         errors.VerificationError) as e:
#     474     # These errors are probably from an issue with either the code
#     475     # supplied being syntactically or otherwise invalid
#     476     error_rewrite(e, 'interpreter')
#
# File ~\anaconda3\lib\site-packages\numba\core\dispatcher.py:409, in _DispatcherBase._compile_for_args.<locals>.error_rewrite(e, issue_type)
#     407     raise e
#     408 else:
# --> 409     raise e.with_traceback(None)
#
# UnsupportedError: Failed in nopython mode pipeline (step: analyzing bytecode)
# Use of unsupported opcode (STORE_GLOBAL) found
#
# File "..\..\..\..\AppData\Local\Temp\ipykernel_10596\1572817354.py", line 184:
# <source missing, REPL/exec in use?>

# %%
#checkenv
from stable_baselines3.common.env_checker import check_env
#Start the timer
start_time = time.time()

env = DroneEnv()

# It will check your custom environment and output additional warnings if needed
check_env(env)

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Warehouse 0
# Warehouse 1
# Warehouse 2
# Warehouse 3
# Warehouse 4
# Warehouse 5
# Warehouse 6
# Warehouse 7
# Warehouse 8
# Warehouse 9
#
#
#
# ordArrayMaster doesnt exist yet. Make a master and a copy
# --- 0.30202484130859375 seconds ---

# %%
Warehouse.getQty()
# Out:
# 0

# %%
#Doublecheck
import stable_baselines3
from stable_baselines3.common.env_checker import check_env
#Start the timer
start_time = time.time()
rewardList=list()
env = DroneEnv()

episodes = 5
for episode in range(episodes):
    
    done = False
    obs = env.reset()
    while not done:
        random_action = env.action_space.sample()
        #print("action",random_action)
        obs, reward, done, info = env.step(random_action)
        rewardList.append(reward)
        #if random_action[1]==2 and reward !=-3.5 and reward !=-3.6:
        #    print("==>random action: {}   reward:{}  done:{}".format(random_action,reward,done) )
        #if reward>=-1:
        #   print("random action: {}   reward:{}  done:{}".format(random_action,reward,done) )

print("--- %s seconds ---" % (time.time() - start_time))  
#print(rewardList)
rewardList=list(set(rewardList))
rewardList2=list()
for i in rewardList:
    if int(i*100)/100 == i:
        rewardList2.append(i)

print("Rewards:{}".format(sorted(rewardList2)))
# Out:
# All orders completed! (11) in 43 manifest steps
# Drone:0 was the last to finish. The finish time was:1286
# Padding drone:0 with 111707 units of time
# Padding drone:1 with 111845 units of time
# Padding drone:2 with 112272 units of time
# Padding drone:3 with 112151 units of time
# Padding drone:4 with 112993 units of time
# Padding drone:5 with 112993 units of time
# Padding drone:6 with 112993 units of time
# Padding drone:7 with 112993 units of time
# Padding drone:8 with 112993 units of time
# Padding drone:9 with 112993 units of time
# Padding drone:10 with 112993 units of time
# Padding drone:11 with 112993 units of time
# Padding drone:12 with 112993 units of time
# Padding drone:13 with 112993 units of time
# Padding drone:14 with 112993 units of time
# Padding drone:15 with 112993 units of time
# Padding drone:16 with 112993 units of time
# Padding drone:17 with 112993 units of time
# Padding drone:18 with 112993 units of time
# Padding drone:19 with 112993 units of time
# Padding drone:20 with 112993 units of time
# Padding drone:21 with 112993 units of time
# Padding drone:22 with 112993 units of time
# Padding drone:23 with 112993 units of time
# Padding drone:24 with 112993 units of time
# Padding drone:25 with 112993 units of time
# Padding drone:26 with 112993 units of time
# Padding drone:27 with 112993 units of time
# Padding drone:28 with 112993 units of time
# Padding drone:29 with 112993 units of time
# All orders completed! (11) in 53 manifest steps
# Drone:3 was the last to finish. The finish time was:1336
# Padding drone:0 with 111944 units of time
# Padding drone:1 with 112868 units of time
# Padding drone:2 with 112217 units of time
# Padding drone:3 with 111657 units of time
# Padding drone:4 with 112212 units of time
# Padding drone:5 with 112993 units of time
# Padding drone:6 with 112993 units of time
# Padding drone:7 with 112993 units of time
# Padding drone:8 with 112993 units of time
# Padding drone:9 with 112993 units of time
# Padding drone:10 with 112993 units of time
# Padding drone:11 with 112993 units of time
# Padding drone:12 with 112993 units of time
# Padding drone:13 with 112993 units of time
# Padding drone:14 with 112993 units of time
# Padding drone:15 with 112993 units of time
# Padding drone:16 with 112993 units of time
# Padding drone:17 with 112993 units of time
# Padding drone:18 with 112993 units of time
# Padding drone:19 with 112993 units of time
# Padding drone:20 with 112993 units of time
# Padding drone:21 with 112993 units of time
# Padding drone:22 with 112993 units of time
# Padding drone:23 with 112993 units of time
# Padding drone:24 with 112993 units of time
# Padding drone:25 with 112993 units of time
# Padding drone:26 with 112993 units of time
# Padding drone:27 with 112993 units of time
# Padding drone:28 with 112993 units of time
# Padding drone:29 with 112993 units of time
# All orders completed! (11) in 77 manifest steps
# Drone:0 was the last to finish. The finish time was:1170
# Padding drone:0 with 111823 units of time
# Padding drone:1 with 112394 units of time
# Padding drone:2 with 111989 units of time
# Padding drone:3 with 112323 units of time
# Padding drone:4 with 112993 units of time
# Padding drone:5 with 112993 units of time
# Padding drone:6 with 112993 units of time
# Padding drone:7 with 112993 units of time
# Padding drone:8 with 112993 units of time
# Padding drone:9 with 112993 units of time
# Padding drone:10 with 112993 units of time
# Padding drone:11 with 112993 units of time
# Padding drone:12 with 112993 units of time
# Padding drone:13 with 112993 units of time
# Padding drone:14 with 112993 units of time
# Padding drone:15 with 112993 units of time
# Padding drone:16 with 112993 units of time
# Padding drone:17 with 112993 units of time
# Padding drone:18 with 112993 units of time
# Padding drone:19 with 112993 units of time
# Padding drone:20 with 112993 units of time
# Padding drone:21 with 112993 units of time
# Padding drone:22 with 112993 units of time
# Padding drone:23 with 112993 units of time
# Padding drone:24 with 112993 units of time
# Padding drone:25 with 112993 units of time
# Padding drone:26 with 112993 units of time
# Padding drone:27 with 112993 units of time
# Padding drone:28 with 112993 units of time
# Padding drone:29 with 112993 units of time
# All orders completed! (11) in 34 manifest steps
# Drone:3 was the last to finish. The finish time was:1080
# Padding drone:0 with 112868 units of time
# Padding drone:1 with 111944 units of time
# Padding drone:2 with 112111 units of time
# Padding drone:3 with 111913 units of time
# Padding drone:4 with 112272 units of time
# Padding drone:5 with 112993 units of time
# Padding drone:6 with 112993 units of time
# Padding drone:7 with 112993 units of time
# Padding drone:8 with 112993 units of time
# Padding drone:9 with 112993 units of time
# Padding drone:10 with 112993 units of time
# Padding drone:11 with 112993 units of time
# Padding drone:12 with 112993 units of time
# Padding drone:13 with 112993 units of time
# Padding drone:14 with 112993 units of time
# Padding drone:15 with 112993 units of time
# Padding drone:16 with 112993 units of time
# Padding drone:17 with 112993 units of time
# Padding drone:18 with 112993 units of time
# Padding drone:19 with 112993 units of time
# Padding drone:20 with 112993 units of time
# Padding drone:21 with 112993 units of time
# Padding drone:22 with 112993 units of time
# Padding drone:23 with 112993 units of time
# Padding drone:24 with 112993 units of time
# Padding drone:25 with 112993 units of time
# Padding drone:26 with 112993 units of time
# Padding drone:27 with 112993 units of time
# Padding drone:28 with 112993 units of time
# Padding drone:29 with 112993 units of time
# All orders completed! (11) in 78 manifest steps
# Drone:2 was the last to finish. The finish time was:1141
# Padding drone:0 with 112066 units of time
# Padding drone:1 with 112078 units of time
# Padding drone:2 with 111852 units of time
# Padding drone:3 with 112088 units of time
# Padding drone:4 with 112993 units of time
# Padding drone:5 with 112993 units of time
# Padding drone:6 with 112993 units of time
# Padding drone:7 with 112993 units of time
# Padding drone:8 with 112993 units of time
# Padding drone:9 with 112993 units of time
# Padding drone:10 with 112993 units of time
# Padding drone:11 with 112993 units of time
# Padding drone:12 with 112993 units of time
# Padding drone:13 with 112993 units of time
# Padding drone:14 with 112993 units of time
# Padding drone:15 with 112993 units of time
# Padding drone:16 with 112993 units of time
# Padding drone:17 with 112993 units of time
# Padding drone:18 with 112993 units of time
# Padding drone:19 with 112993 units of time
# Padding drone:20 with 112993 units of time
# Padding drone:21 with 112993 units of time
# Padding drone:22 with 112993 units of time
# Padding drone:23 with 112993 units of time
# Padding drone:24 with 112993 units of time
# Padding drone:25 with 112993 units of time
# Padding drone:26 with 112993 units of time
# Padding drone:27 with 112993 units of time
# Padding drone:28 with 112993 units of time
# Padding drone:29 with 112993 units of time
# --- 1.029048204421997 seconds ---
# Rewards:[0, 1]

# %%
To Monitor the learning:
    from a command prompt:
    cd C:\Users\greg\Documents\GitHub\DroneDelivery_v2\code\logs
    tensorboard --logdir=. 
    then open a browser window to:http://localhost:6006/

# %%
# dronelearn.py
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.evaluation import evaluate_policy
import os
#from droneenv import DroneEnv
import time



models_dir = f"models/{int(time.time())}/"
logdir = f"logs/{int(time.time())}/"

if not os.path.exists(models_dir):
	os.makedirs(models_dir)

if not os.path.exists(logdir):
	os.makedirs(logdir)

env = DroneEnv()
env.reset()
env = Monitor(env, logdir)

model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=logdir,device='cpu')
#mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=1)
TIMESTEPS = 100000
iters = 0
while iters<=9:
    iters += 1
    model.learn(total_timesteps=TIMESTEPS, reset_num_timesteps=False, tb_log_name=f"PPO")
    model.save(f"{models_dir}/{TIMESTEPS*iters}")
    #mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=1)
# Out:
# Warehouse 0
# Warehouse 1
# Warehouse 2
# Warehouse 3
# Warehouse 4
# Warehouse 5
# Warehouse 6
# Warehouse 7
# Warehouse 8
# Warehouse 9
#
#
#
# ordArrayMaster doesnt exist yet. Make a master and a copy
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# Logging to logs/1671973003/PPO_0
# -----------------------------
# | time/              |      |
# |    fps             | 26   |
# |    iterations      | 1    |
# |    time_elapsed    | 76   |
# |    total_timesteps | 2048 |
# -----------------------------
# Hit manifest seq number limit of 3999 Ending episode with 1281 successful deliveries
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4e+03         |
# |    ep_rew_mean          | 1.56e+05      |
# | time/                   |               |
# |    fps                  | 27            |
# |    iterations           | 2             |
# |    time_elapsed         | 147           |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.00019407473 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.61         |
# |    explained_variance   | 6.74e-06      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.94e+05      |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.00089      |
# |    value_loss           | 6.59e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4e+03        |
# |    ep_rew_mean          | 1.56e+05     |
# | time/                   |              |
# |    fps                  | 28           |
# |    iterations           | 3            |
# |    time_elapsed         | 217          |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0009108248 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.6         |
# |    explained_variance   | 1.14e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.68e+05     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00311     |
# |    value_loss           | 4.43e+05     |
# ------------------------------------------
# Hit manifest seq number limit of 3999 Ending episode with 1175 successful deliveries
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4e+03        |
# |    ep_rew_mean          | 1.48e+05     |
# | time/                   |              |
# |    fps                  | 28           |
# |    iterations           | 4            |
# |    time_elapsed         | 285          |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0004126985 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.6         |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.38e+05     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00126     |
# |    value_loss           | 5.24e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4e+03        |
# |    ep_rew_mean          | 1.48e+05     |
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 5            |
# |    time_elapsed         | 352          |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0010956776 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.6         |
# |    explained_variance   | -5.96e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.39e+05     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00265     |
# |    value_loss           | 3.98e+05     |
# ------------------------------------------
# Hit manifest seq number limit of 3999 Ending episode with 1209 successful deliveries
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4e+03        |
# |    ep_rew_mean          | 1.48e+05     |
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 6            |
# |    time_elapsed         | 418          |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0004707675 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.6         |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.71e+05     |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0012      |
# |    value_loss           | 4.95e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4e+03        |
# |    ep_rew_mean          | 1.48e+05     |
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 7            |
# |    time_elapsed         | 486          |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0007700614 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.6         |
# |    explained_variance   | -7.15e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.2e+05      |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00193     |
# |    value_loss           | 6.08e+05     |
# ------------------------------------------
# Hit manifest seq number limit of 3999 Ending episode with 1332 successful deliveries
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4e+03        |
# |    ep_rew_mean          | 1.51e+05     |
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 8            |
# |    time_elapsed         | 554          |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0015359194 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.59        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.52e+05     |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00303     |
# |    value_loss           | 4.82e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4e+03        |
# |    ep_rew_mean          | 1.51e+05     |
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 9            |
# |    time_elapsed         | 622          |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0010106835 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.59        |
# |    explained_variance   | -4.77e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.86e+05     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00253     |
# |    value_loss           | 5.39e+05     |
# ------------------------------------------
# Hit manifest seq number limit of 3999 Ending episode with 1225 successful deliveries
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4e+03        |
# |    ep_rew_mean          | 1.5e+05      |
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 10           |
# |    time_elapsed         | 690          |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0009378075 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.59        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.22e+05     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00178     |
# |    value_loss           | 4.65e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4e+03        |
# |    ep_rew_mean          | 1.5e+05      |
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 11           |
# |    time_elapsed         | 761          |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0014775937 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.59        |
# |    explained_variance   | -3.58e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.62e+05     |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00295     |
# |    value_loss           | 5.74e+05     |
# ------------------------------------------
# Hit manifest seq number limit of 3999 Ending episode with 1300 successful deliveries
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4e+03        |
# |    ep_rew_mean          | 1.51e+05     |
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 12           |
# |    time_elapsed         | 829          |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0018652508 |
# |    clip_fraction        | 0.000391     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.58        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.49e+05     |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00355     |
# |    value_loss           | 4.89e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4e+03         |
# |    ep_rew_mean          | 1.51e+05      |
# | time/                   |               |
# |    fps                  | 29            |
# |    iterations           | 13            |
# |    time_elapsed         | 896           |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 0.00093416224 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.58         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.61e+05      |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.00176      |
# |    value_loss           | 5.11e+05      |
# -------------------------------------------
# Hit manifest seq number limit of 3999 Ending episode with 1293 successful deliveries
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4e+03        |
# |    ep_rew_mean          | 1.52e+05     |
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 14           |
# |    time_elapsed         | 964          |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0020755245 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.57        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.29e+05     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00289     |
# |    value_loss           | 4.94e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4e+03         |
# |    ep_rew_mean          | 1.52e+05      |
# | time/                   |               |
# |    fps                  | 29            |
# |    iterations           | 15            |
# |    time_elapsed         | 1031          |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 0.00074072974 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.57         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.71e+05      |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.00111      |
# |    value_loss           | 5.3e+05       |
# -------------------------------------------
# Hit manifest seq number limit of 3999 Ending episode with 1294 successful deliveries
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4e+03        |
# |    ep_rew_mean          | 1.52e+05     |
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 16           |
# |    time_elapsed         | 1099         |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0035103862 |
# |    clip_fraction        | 0.000684     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.55        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.46e+05     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00473     |
# |    value_loss           | 4.93e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4e+03       |
# |    ep_rew_mean          | 1.52e+05    |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 17          |
# |    time_elapsed         | 1167        |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.005583844 |
# |    clip_fraction        | 0.00513     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.53       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.38e+05    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00528    |
# |    value_loss           | 4.79e+05    |
# -----------------------------------------
# Hit manifest seq number limit of 3999 Ending episode with 1341 successful deliveries
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4e+03        |
# |    ep_rew_mean          | 1.53e+05     |
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 18           |
# |    time_elapsed         | 1235         |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0059272787 |
# |    clip_fraction        | 0.0128       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.49        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.88e+05     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00599     |
# |    value_loss           | 4.94e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4e+03        |
# |    ep_rew_mean          | 1.53e+05     |
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 19           |
# |    time_elapsed         | 1303         |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0016563507 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.48        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.24e+05     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00196     |
# |    value_loss           | 5.33e+05     |
# ------------------------------------------
# Hit manifest seq number limit of 3999 Ending episode with 1349 successful deliveries
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4e+03        |
# |    ep_rew_mean          | 1.53e+05     |
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 20           |
# |    time_elapsed         | 1371         |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0042099236 |
# |    clip_fraction        | 0.00361      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.46        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.83e+05     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00403     |
# |    value_loss           | 5.01e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4e+03        |
# |    ep_rew_mean          | 1.53e+05     |
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 21           |
# |    time_elapsed         | 1438         |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0037851273 |
# |    clip_fraction        | 0.00249      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.47        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.76e+05     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.0038      |
# |    value_loss           | 6.13e+05     |
# ------------------------------------------
# Hit manifest seq number limit of 3999 Ending episode with 1419 successful deliveries
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4e+03        |
# |    ep_rew_mean          | 1.54e+05     |
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 22           |
# |    time_elapsed         | 1506         |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0061115967 |
# |    clip_fraction        | 0.0193       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.43        |
# |    explained_variance   | 1.79e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.52e+05     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00632     |
# |    value_loss           | 5.05e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4e+03        |
# |    ep_rew_mean          | 1.54e+05     |
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 23           |
# |    time_elapsed         | 1573         |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0044843513 |
# |    clip_fraction        | 0.00244      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.41        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.72e+05     |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00393     |
# |    value_loss           | 6.1e+05      |
# ------------------------------------------
# Hit manifest seq number limit of 3999 Ending episode with 1575 successful deliveries
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4e+03        |
# |    ep_rew_mean          | 1.56e+05     |
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 24           |
# |    time_elapsed         | 1641         |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0041735256 |
# |    clip_fraction        | 0.0111       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.34        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.56e+05     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00371     |
# |    value_loss           | 5.8e+05      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4e+03        |
# |    ep_rew_mean          | 1.56e+05     |
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 25           |
# |    time_elapsed         | 1709         |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0036083045 |
# |    clip_fraction        | 0.00908      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.32        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.42e+05     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00402     |
# |    value_loss           | 8.39e+05     |
# ------------------------------------------
# Hit manifest seq number limit of 3999 Ending episode with 1693 successful deliveries
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4e+03      |
# |    ep_rew_mean          | 1.59e+05   |
# | time/                   |            |
# |    fps                  | 29         |
# |    iterations           | 26         |
# |    time_elapsed         | 1777       |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.00655489 |
# |    clip_fraction        | 0.0159     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.27      |
# |    explained_variance   | 1.19e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.46e+05   |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.0059    |
# |    value_loss           | 6.41e+05   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4e+03        |
# |    ep_rew_mean          | 1.59e+05     |
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 27           |
# |    time_elapsed         | 1845         |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0069113616 |
# |    clip_fraction        | 0.0351       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.22        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.99e+05     |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00806     |
# |    value_loss           | 1.06e+06     |
# ------------------------------------------
# Hit manifest seq number limit of 3999 Ending episode with 1881 successful deliveries
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4e+03        |
# |    ep_rew_mean          | 1.63e+05     |
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 28           |
# |    time_elapsed         | 1913         |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0057768393 |
# |    clip_fraction        | 0.0435       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.15        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.89e+05     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.011       |
# |    value_loss           | 7.79e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4e+03       |
# |    ep_rew_mean          | 1.63e+05    |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 29          |
# |    time_elapsed         | 1981        |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.006913084 |
# |    clip_fraction        | 0.0351      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.07       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.21e+05    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00881    |
# |    value_loss           | 1.18e+06    |
# -----------------------------------------
# Hit manifest seq number limit of 3999 Ending episode with 2053 successful deliveries
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4e+03        |
# |    ep_rew_mean          | 1.68e+05     |
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 30           |
# |    time_elapsed         | 2049         |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0059680706 |
# |    clip_fraction        | 0.0355       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.02        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.84e+05     |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00773     |
# |    value_loss           | 9.62e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4e+03        |
# |    ep_rew_mean          | 1.68e+05     |
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 31           |
# |    time_elapsed         | 2116         |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0059636803 |
# |    clip_fraction        | 0.0581       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.88        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.58e+05     |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.0107      |
# |    value_loss           | 1.51e+06     |
# ------------------------------------------
# Hit manifest seq number limit of 3999 Ending episode with 2387 successful deliveries
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4e+03       |
# |    ep_rew_mean          | 1.74e+05    |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 32          |
# |    time_elapsed         | 2185        |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.009447403 |
# |    clip_fraction        | 0.0806      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.83       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.83e+05    |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0152     |
# |    value_loss           | 9.94e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4e+03       |
# |    ep_rew_mean          | 1.74e+05    |
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 33          |
# |    time_elapsed         | 2252        |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.011324661 |
# |    clip_fraction        | 0.0695      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.62       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.41e+05    |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 1.78e+06    |
# -----------------------------------------
# Hit manifest seq number limit of 3999 Ending episode with 2762 successful deliveries
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4e+03        |
# |    ep_rew_mean          | 1.81e+05     |
# | time/                   |              |
# |    fps                  | 30           |
# |    iterations           | 34           |
# |    time_elapsed         | 2319         |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0076197223 |
# |    clip_fraction        | 0.133        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.54        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.31e+05     |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.0197      |
# |    value_loss           | 1.56e+06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4e+03       |
# |    ep_rew_mean          | 1.81e+05    |
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 35          |
# |    time_elapsed         | 2386        |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.010277569 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.3        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.6e+06     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0216     |
# |    value_loss           | 3.2e+06     |
# -----------------------------------------
# Hit manifest seq number limit of 3999 Ending episode with 3577 successful deliveries
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4e+03       |
# |    ep_rew_mean          | 1.93e+05    |
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 36          |
# |    time_elapsed         | 2454        |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.012402754 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.2        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.06e+06    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0253     |
# |    value_loss           | 2.05e+06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4e+03       |
# |    ep_rew_mean          | 1.93e+05    |
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 37          |
# |    time_elapsed         | 2521        |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.012225734 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.89       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.18e+06    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0183     |
# |    value_loss           | 4.29e+06    |
# -----------------------------------------
# Hit manifest seq number limit of 3999 Ending episode with 4605 successful deliveries
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4e+03       |
# |    ep_rew_mean          | 2.07e+05    |
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 38          |
# |    time_elapsed         | 2590        |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.013286581 |
# |    clip_fraction        | 0.277       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.76       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.74e+06    |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0296     |
# |    value_loss           | 3.45e+06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4e+03       |
# |    ep_rew_mean          | 2.07e+05    |
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 39          |
# |    time_elapsed         | 2659        |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.019992577 |
# |    clip_fraction        | 0.0991      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.39       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.85e+06    |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0175     |
# |    value_loss           | 6.64e+06    |
# -----------------------------------------
# Hit manifest seq number limit of 3999 Ending episode with 5823 successful deliveries
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4e+03       |
# |    ep_rew_mean          | 2.25e+05    |
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 40          |
# |    time_elapsed         | 2729        |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.026067823 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.21       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.24e+06    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.024      |
# |    value_loss           | 4.71e+06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4e+03        |
# |    ep_rew_mean          | 2.25e+05     |
# | time/                   |              |
# |    fps                  | 30           |
# |    iterations           | 41           |
# |    time_elapsed         | 2798         |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0091771595 |
# |    clip_fraction        | 0.0262       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.76        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.04e+06     |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.0115      |
# |    value_loss           | 1.22e+07     |
# ------------------------------------------
# Hit manifest seq number limit of 3999 Ending episode with 7333 successful deliveries
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4e+03       |
# |    ep_rew_mean          | 2.47e+05    |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 42          |
# |    time_elapsed         | 2867        |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.018293962 |
# |    clip_fraction        | 0.0534      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.89       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.25e+06    |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0135     |
# |    value_loss           | 4.78e+06    |
# -----------------------------------------
# Hit manifest seq number limit of 3999 Ending episode with 8660 successful deliveries
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4e+03        |
# |    ep_rew_mean          | 2.69e+05     |
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 43           |
# |    time_elapsed         | 2938         |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0045204023 |
# |    clip_fraction        | 0.00869      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.06e+06     |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00823     |
# |    value_loss           | 1.68e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4e+03        |
# |    ep_rew_mean          | 2.69e+05     |
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 44           |
# |    time_elapsed         | 3007         |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0062062507 |
# |    clip_fraction        | 0.017        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.51        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.58e+06     |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00546     |
# |    value_loss           | 5.14e+06     |
# ------------------------------------------
# Hit manifest seq number limit of 3999 Ending episode with 9195 successful deliveries
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4e+03        |
# |    ep_rew_mean          | 2.91e+05     |
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 45           |
# |    time_elapsed         | 3079         |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0013604177 |
# |    clip_fraction        | 0.00083      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.984       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.94e+06     |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00313     |
# |    value_loss           | 1.83e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4e+03        |
# |    ep_rew_mean          | 2.91e+05     |
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 46           |
# |    time_elapsed         | 3151         |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0030129086 |
# |    clip_fraction        | 0.0062       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 1.79e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.33e+06     |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.0029      |
# |    value_loss           | 6.1e+06      |
# ------------------------------------------
# All orders completed! (9368) in 3902 manifest steps
# Drone:2 was the last to finish. The finish time was:92522
# Padding drone:0 with 21331 units of time
# Padding drone:1 with 20516 units of time
# Padding drone:2 with 20471 units of time
# Padding drone:3 with 21307 units of time
# Padding drone:4 with 21266 units of time
# Padding drone:5 with 20691 units of time
# Padding drone:6 with 20838 units of time
# Padding drone:7 with 20621 units of time
# Padding drone:8 with 20743 units of time
# Padding drone:9 with 20672 units of time
# Padding drone:10 with 20610 units of time
# Padding drone:11 with 20665 units of time
# Padding drone:12 with 20692 units of time
# Padding drone:13 with 20742 units of time
# Padding drone:14 with 20549 units of time
# Padding drone:15 with 21401 units of time
# Padding drone:16 with 21068 units of time
# Padding drone:17 with 21297 units of time
# Padding drone:18 with 21349 units of time
# Padding drone:19 with 20499 units of time
# Padding drone:20 with 20569 units of time
# Padding drone:21 with 20540 units of time
# Padding drone:22 with 20660 units of time
# Padding drone:23 with 21022 units of time
# Padding drone:24 with 20965 units of time
# Padding drone:25 with 21193 units of time
# Padding drone:26 with 20662 units of time
# Padding drone:27 with 20512 units of time
# Padding drone:28 with 21264 units of time
# Padding drone:29 with 21243 units of time
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.99e+03     |
# |    ep_rew_mean          | 3.11e+05     |
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 47           |
# |    time_elapsed         | 3223         |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0012234877 |
# |    clip_fraction        | 0.00083      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.832       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.23e+06     |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00314     |
# |    value_loss           | 1.86e+07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.99e+03      |
# |    ep_rew_mean          | 3.11e+05      |
# | time/                   |               |
# |    fps                  | 29            |
# |    iterations           | 48            |
# |    time_elapsed         | 3294          |
# |    total_timesteps      | 98304         |
# | train/                  |               |
# |    approx_kl            | 0.00018579699 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.12         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.72e+06      |
# |    n_updates            | 470           |
# |    policy_gradient_loss | -0.000402     |
# |    value_loss           | 8.28e+06      |
# -------------------------------------------
# All orders completed! (9368) in 3773 manifest steps
# Drone:22 was the last to finish. The finish time was:92079
# Padding drone:0 with 21072 units of time
# Padding drone:1 with 21350 units of time
# Padding drone:2 with 21515 units of time
# Padding drone:3 with 21858 units of time
# Padding drone:4 with 21390 units of time
# Padding drone:5 with 21129 units of time
# Padding drone:6 with 21230 units of time
# Padding drone:7 with 21853 units of time
# Padding drone:8 with 21677 units of time
# Padding drone:9 with 21129 units of time
# Padding drone:10 with 21770 units of time
# Padding drone:11 with 21635 units of time
# Padding drone:12 with 21572 units of time
# Padding drone:13 with 21730 units of time
# Padding drone:14 with 21048 units of time
# Padding drone:15 with 21579 units of time
# Padding drone:16 with 21131 units of time
# Padding drone:17 with 21106 units of time
# Padding drone:18 with 21275 units of time
# Padding drone:19 with 21035 units of time
# Padding drone:20 with 21055 units of time
# Padding drone:21 with 21937 units of time
# Padding drone:22 with 20914 units of time
# Padding drone:23 with 21479 units of time
# Padding drone:24 with 20948 units of time
# Padding drone:25 with 21310 units of time
# Padding drone:26 with 21680 units of time
# Padding drone:27 with 21170 units of time
# Padding drone:28 with 21684 units of time
# Padding drone:29 with 21049 units of time
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.99e+03     |
# |    ep_rew_mean          | 3.29e+05     |
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 49           |
# |    time_elapsed         | 3366         |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0007713987 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# ...
# Padding drone:9 with 22988 units of time
# Padding drone:10 with 23119 units of time
# Padding drone:11 with 22241 units of time
# Padding drone:12 with 22631 units of time
# Padding drone:13 with 22520 units of time
# Padding drone:14 with 22319 units of time
# Padding drone:15 with 22603 units of time
# Padding drone:16 with 22385 units of time
# Padding drone:17 with 22944 units of time
# Padding drone:18 with 22753 units of time
# Padding drone:19 with 22455 units of time
# Padding drone:20 with 22920 units of time
# Padding drone:21 with 22865 units of time
# Padding drone:22 with 22492 units of time
# Padding drone:23 with 22128 units of time
# Padding drone:24 with 22384 units of time
# Padding drone:25 with 22397 units of time
# Padding drone:26 with 22327 units of time
# Padding drone:27 with 22907 units of time
# Padding drone:28 with 22326 units of time
# Padding drone:29 with 22441 units of time
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.19e+03      |
# |    ep_rew_mean          | 7.78e+05      |
# | time/                   |               |
# |    fps                  | 24            |
# |    iterations           | 41            |
# |    time_elapsed         | 3485          |
# |    total_timesteps      | 987136        |
# | train/                  |               |
# |    approx_kl            | 2.3806933e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0279       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 9.27e+06      |
# |    n_updates            | 4810          |
# |    policy_gradient_loss | -2.92e-06     |
# |    value_loss           | 1.93e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.19e+03      |
# |    ep_rew_mean          | 7.78e+05      |
# | time/                   |               |
# |    fps                  | 24            |
# |    iterations           | 42            |
# |    time_elapsed         | 3572          |
# |    total_timesteps      | 989184        |
# | train/                  |               |
# |    approx_kl            | 3.9231963e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0341       |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.43e+06      |
# |    n_updates            | 4820          |
# |    policy_gradient_loss | -1.55e-05     |
# |    value_loss           | 1.61e+07      |
# -------------------------------------------
# All orders completed! (9368) in 3191 manifest steps
# Drone:8 was the last to finish. The finish time was:90860
# Padding drone:0 with 23010 units of time
# Padding drone:1 with 22338 units of time
# Padding drone:2 with 22403 units of time
# Padding drone:3 with 22494 units of time
# Padding drone:4 with 23034 units of time
# Padding drone:5 with 23007 units of time
# Padding drone:6 with 22519 units of time
# Padding drone:7 with 22817 units of time
# Padding drone:8 with 22133 units of time
# Padding drone:9 with 22500 units of time
# Padding drone:10 with 22478 units of time
# Padding drone:11 with 22488 units of time
# Padding drone:12 with 23173 units of time
# Padding drone:13 with 23147 units of time
# Padding drone:14 with 22371 units of time
# Padding drone:15 with 22874 units of time
# Padding drone:16 with 22388 units of time
# Padding drone:17 with 22453 units of time
# Padding drone:18 with 22399 units of time
# Padding drone:19 with 22716 units of time
# Padding drone:20 with 23225 units of time
# Padding drone:21 with 23154 units of time
# Padding drone:22 with 22504 units of time
# Padding drone:23 with 22499 units of time
# Padding drone:24 with 23023 units of time
# Padding drone:25 with 22673 units of time
# Padding drone:26 with 22522 units of time
# Padding drone:27 with 23134 units of time
# Padding drone:28 with 22790 units of time
# Padding drone:29 with 22671 units of time
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.19e+03      |
# |    ep_rew_mean          | 7.78e+05      |
# | time/                   |               |
# |    fps                  | 24            |
# |    iterations           | 43            |
# |    time_elapsed         | 3655          |
# |    total_timesteps      | 991232        |
# | train/                  |               |
# |    approx_kl            | 3.9726729e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0361       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.12e+06      |
# |    n_updates            | 4830          |
# |    policy_gradient_loss | -1.56e-05     |
# |    value_loss           | 8.84e+06      |
# -------------------------------------------
# All orders completed! (9368) in 3196 manifest steps
# Drone:11 was the last to finish. The finish time was:90841
# Padding drone:0 with 22373 units of time
# Padding drone:1 with 22418 units of time
# Padding drone:2 with 22439 units of time
# Padding drone:3 with 22182 units of time
# Padding drone:4 with 22901 units of time
# Padding drone:5 with 22529 units of time
# Padding drone:6 with 22897 units of time
# Padding drone:7 with 22973 units of time
# Padding drone:8 with 23088 units of time
# Padding drone:9 with 22701 units of time
# Padding drone:10 with 22703 units of time
# Padding drone:11 with 22152 units of time
# Padding drone:12 with 23126 units of time
# Padding drone:13 with 22634 units of time
# Padding drone:14 with 22411 units of time
# Padding drone:15 with 22923 units of time
# Padding drone:16 with 22410 units of time
# Padding drone:17 with 22668 units of time
# Padding drone:18 with 23106 units of time
# Padding drone:19 with 22729 units of time
# Padding drone:20 with 22670 units of time
# Padding drone:21 with 22423 units of time
# Padding drone:22 with 22316 units of time
# Padding drone:23 with 22368 units of time
# Padding drone:24 with 22404 units of time
# Padding drone:25 with 22598 units of time
# Padding drone:26 with 22241 units of time
# Padding drone:27 with 22977 units of time
# Padding drone:28 with 22952 units of time
# Padding drone:29 with 22296 units of time
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.19e+03      |
# |    ep_rew_mean          | 7.78e+05      |
# | time/                   |               |
# |    fps                  | 24            |
# |    iterations           | 44            |
# |    time_elapsed         | 3741          |
# |    total_timesteps      | 993280        |
# | train/                  |               |
# |    approx_kl            | 3.7020072e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0269       |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.08e+07      |
# |    n_updates            | 4840          |
# |    policy_gradient_loss | -4.43e-06     |
# |    value_loss           | 2.14e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.19e+03      |
# |    ep_rew_mean          | 7.78e+05      |
# | time/                   |               |
# |    fps                  | 24            |
# |    iterations           | 45            |
# |    time_elapsed         | 3828          |
# |    total_timesteps      | 995328        |
# | train/                  |               |
# |    approx_kl            | 4.5407796e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.035        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 9.02e+06      |
# |    n_updates            | 4850          |
# |    policy_gradient_loss | -1.86e-05     |
# |    value_loss           | 1.43e+07      |
# -------------------------------------------
# All orders completed! (9368) in 3172 manifest steps
# Drone:5 was the last to finish. The finish time was:90198
# Padding drone:0 with 23017 units of time
# Padding drone:1 with 23509 units of time
# Padding drone:2 with 23225 units of time
# Padding drone:3 with 23379 units of time
# Padding drone:4 with 23030 units of time
# Padding drone:5 with 22795 units of time
# Padding drone:6 with 23667 units of time
# Padding drone:7 with 22961 units of time
# Padding drone:8 with 23023 units of time
# Padding drone:9 with 23618 units of time
# Padding drone:10 with 23166 units of time
# Padding drone:11 with 22848 units of time
# Padding drone:12 with 23672 units of time
# Padding drone:13 with 22926 units of time
# Padding drone:14 with 23745 units of time
# Padding drone:15 with 23020 units of time
# Padding drone:16 with 23560 units of time
# Padding drone:17 with 23169 units of time
# Padding drone:18 with 23380 units of time
# Padding drone:19 with 23009 units of time
# Padding drone:20 with 22853 units of time
# Padding drone:21 with 23028 units of time
# Padding drone:22 with 23741 units of time
# Padding drone:23 with 23675 units of time
# Padding drone:24 with 23100 units of time
# Padding drone:25 with 23636 units of time
# Padding drone:26 with 23025 units of time
# Padding drone:27 with 22885 units of time
# Padding drone:28 with 23656 units of time
# Padding drone:29 with 23023 units of time
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.19e+03      |
# |    ep_rew_mean          | 7.78e+05      |
# | time/                   |               |
# |    fps                  | 24            |
# |    iterations           | 46            |
# |    time_elapsed         | 3913          |
# |    total_timesteps      | 997376        |
# | train/                  |               |
# |    approx_kl            | 1.1289376e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0316       |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.88e+06      |
# |    n_updates            | 4860          |
# |    policy_gradient_loss | -9.22e-06     |
# |    value_loss           | 1.12e+07      |
# -------------------------------------------
# All orders completed! (9368) in 3186 manifest steps
# Drone:4 was the last to finish. The finish time was:90360
# Padding drone:0 with 23124 units of time
# Padding drone:1 with 22741 units of time
# Padding drone:2 with 22736 units of time
# Padding drone:3 with 23520 units of time
# Padding drone:4 with 22633 units of time
# Padding drone:5 with 22826 units of time
# Padding drone:6 with 23507 units of time
# Padding drone:7 with 22818 units of time
# Padding drone:8 with 23501 units of time
# Padding drone:9 with 22814 units of time
# Padding drone:10 with 23511 units of time
# Padding drone:11 with 23485 units of time
# Padding drone:12 with 23459 units of time
# Padding drone:13 with 22805 units of time
# Padding drone:14 with 23475 units of time
# Padding drone:15 with 23477 units of time
# Padding drone:16 with 22830 units of time
# Padding drone:17 with 23472 units of time
# Padding drone:18 with 22924 units of time
# Padding drone:19 with 22842 units of time
# Padding drone:20 with 22670 units of time
# Padding drone:21 with 22904 units of time
# Padding drone:22 with 22924 units of time
# Padding drone:23 with 23386 units of time
# Padding drone:24 with 22645 units of time
# Padding drone:25 with 22701 units of time
# Padding drone:26 with 22821 units of time
# Padding drone:27 with 23537 units of time
# Padding drone:28 with 23478 units of time
# Padding drone:29 with 22838 units of time
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.19e+03      |
# |    ep_rew_mean          | 7.78e+05      |
# | time/                   |               |
# |    fps                  | 24            |
# |    iterations           | 47            |
# |    time_elapsed         | 3998          |
# |    total_timesteps      | 999424        |
# | train/                  |               |
# |    approx_kl            | 3.6437996e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0297       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1e+07         |
# |    n_updates            | 4870          |
# |    policy_gradient_loss | -8.82e-06     |
# |    value_loss           | 2.02e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.19e+03      |
# |    ep_rew_mean          | 7.78e+05      |
# | time/                   |               |
# |    fps                  | 24            |
# |    iterations           | 48            |
# |    time_elapsed         | 4085          |
# |    total_timesteps      | 1001472       |
# | train/                  |               |
# |    approx_kl            | 2.2581662e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0355       |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.1e+06       |
# |    n_updates            | 4880          |
# |    policy_gradient_loss | -1.34e-05     |
# |    value_loss           | 1.3e+07       |
# -------------------------------------------
# All orders completed! (9368) in 3186 manifest steps
# Drone:12 was the last to finish. The finish time was:90240
# Padding drone:0 with 23604 units of time
# Padding drone:1 with 22893 units of time
# Padding drone:2 with 23615 units of time
# Padding drone:3 with 23194 units of time
# Padding drone:4 with 23564 units of time
# Padding drone:5 with 22778 units of time
# Padding drone:6 with 23075 units of time
# Padding drone:7 with 22838 units of time
# Padding drone:8 with 22978 units of time
# Padding drone:9 with 23687 units of time
# Padding drone:10 with 23694 units of time
# Padding drone:11 with 23053 units of time
# Padding drone:12 with 22753 units of time
# Padding drone:13 with 22786 units of time
# Padding drone:14 with 23134 units of time
# Padding drone:15 with 22809 units of time
# Padding drone:16 with 23024 units of time
# Padding drone:17 with 22822 units of time
# Padding drone:18 with 22945 units of time
# Padding drone:19 with 23386 units of time
# Padding drone:20 with 22948 units of time
# Padding drone:21 with 23330 units of time
# Padding drone:22 with 23543 units of time
# Padding drone:23 with 23503 units of time
# Padding drone:24 with 22886 units of time
# Padding drone:25 with 23553 units of time
# Padding drone:26 with 22858 units of time
# Padding drone:27 with 22773 units of time
# Padding drone:28 with 22930 units of time
# Padding drone:29 with 23646 units of time
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.19e+03     |
# |    ep_rew_mean          | 7.78e+05     |
# | time/                   |              |
# |    fps                  | 24           |
# |    iterations           | 49           |
# |    time_elapsed         | 4170         |
# |    total_timesteps      | 1003520      |
# | train/                  |              |
# |    approx_kl            | 4.877802e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0298      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.88e+06     |
# |    n_updates            | 4890         |
# |    policy_gradient_loss | -6e-06       |
# |    value_loss           | 1.34e+07     |
# ------------------------------------------

# %%
l[0].getLine()
# Out:
# '0 L 0 272 1'

# %%
Drone.getQty()
# Out:
# 30

# %%
#Load a model and query
# import libraries and packages
from icecream import ic
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import gym
from stable_baselines3 import PPO
import os
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.evaluation import evaluate_policy

import time
#Start the timer
start_time = time.time()

#/kaggle/input/1670545548-minimal-test-1
logdir = f"/kaggle/working/"
logdir = f"logs/"
env = DroneEnv()
env.reset()
env = Monitor(env, logdir)
#C:\Users\greg\Documents\GitHub\DATA3402\Exams\Final\ML_snek\models\1670214614
#model_path = f"{models_dir}/1670545548-minimal-test-1"
#Use model path from previous cell
#filename="990000"
#working_dir="/kaggle/working/"
#subdir="models/1670617724"
#fileWithPath=f"{working_dir}{subdir}/{filename}"
models_dir = f"models/{int(time.time())}/"
models_dir = f"models/1671822393/"
#input_dir = f"/kaggle/input/"
working_dir = f"/kaggle/working/"
working_dir = f"./"
#model_path = f"{working_dir}1670545548-minimal-test-1"
TIMESTEPS = 50000
iters = 10
lastFile=f"{working_dir}{models_dir}{TIMESTEPS*iters}"
lastFile=f"{working_dir}{models_dir}{TIMESTEPS*iters}"

fileWithPath=lastFile
ic(fileWithPath)

#raise SystemExit("Stop right there!") 
model = PPO.load(fileWithPath, env=env)
#model = PPO("MlpPolicy", env, verbose=1, tensorboard_log = logdir)
episodes = 1
data=list()
#log=list()
for ep in range(episodes):
    obs = env.reset()
    done = False
    i=0
    while not done:
        
        action, _states = model.predict(obs)
        obs, reward, done, info = env.step(action)
        #obs[0]=i
        i+=1
        
        #log.append( (str(action[0])+" "+LUDW+" "+str(action[2])+" "+str(action[3])+" 1"))
print("--- %s seconds ---" % (time.time() - start_time))   
raise SystemExit("Stop right there!") 
# create DataFrame using data
df = pd.DataFrame(data, columns =['drone', 'LUDW', 'param1','prodNum','reward'])

#Count the total distance traveled & time for each drone
#Remember: loading multiple items onto a drone should only count once
newlog=list()
DRONE_QTY=Drone.getQty()
#env = DroneEnv()
#env.reset()
droneDist=[0]*DRONE_QTY
longestDistance=0
for droneNum in range(DRONE_QTY):
    #r,c=startRow,startCol
    elapsedTime=0
    dummy="-1 X -1 -1 -1"
    previousLine=dummy.split()
    prevRow,prevCol=113,179
    currRow,currCol=113,179
    for i in range(Log.getQty()):
        thisLine=l[i].getLine()
        line=thisLine.split()
        #print ("Full line:{} ".format(log[i].getLine())   )
        
        #Review the log lines for this drone in succession
        if int(line[0])==(droneNum):
            #Update the current position based on the log action
            if line[1]=="L" or line[1]=="U":
                DEBUG and print("Drone:{} current location: {},{} ".format(droneNum,currRow,currCol ))
                currRow,currCol=w[int(line[2])].getPos()
            elif line[1]=="D":
                orderNum=int(line[2])
                origOrderNum=order[orderNum].getOrderNum()
                cr,cc=order[orderNum].getPos()
                DEBUG and print("Drone:{} current location: {},{} ".format(droneNum,currRow,currCol ))
                currRow,currCol=(cr,cc)
                #Change the order number in the log to the original order number
                #log[i]=str(line[0])+" D "+str(origOrderNum)+" "+str(line[3])+" 1"
            elif line[1]=='W':
                elapsedTime+=int(line[2])
            else:
                print("Line: {} in log does not match L/U/D/W. line[1]=<{}>".format(line,line[1]))
            if (currRow,currCol) != (prevRow,prevCol):
                #tally the distance/time
                math.sqrt(    ( prevRow-currRow   )**2 +  ( prevCol-currCol  )**2     )
                distanceFlown=math.ceil(  math.sqrt( (prevRow-currRow)**2 + (prevCol-currCol)**2 ) )
                elapsedTime+=distanceFlown+1  # 1 unit of time for the load duration
                DEBUG and print("{} Drone:{} moved from {},{} to  {},{} Dist:{}    New total={}".format(line,droneNum,prevRow,prevCol,currRow,currCol,distanceFlown+1,elapsedTime))
                #update previous location to current location
                prevRow,prevCol=currRow,currCol
            #if elapsedTime>calc.currentTime():
            #    print("Error 911: Something went wrong!!")
            #    print("Drone: {} Elapsed time:{} is greater than total sim time:{} Delta:{}".format(droneNum,elapsedTime,calc.currentTime(),calc.currentTime()-elapsedTime))
            #    #raise SystemExit("Stop here!")
    droneDist[droneNum]=elapsedTime
    if elapsedTime>longestDistance:
        DEBUG and print("This drone:{} had the longest distance so far:{}".format(droneNum,elapsedTime) )
        longestDistance=elapsedTime
        longestDrone=droneNum
for droneNum in range(DRONE_QTY):
    print("Drone:{}  had a total distance flown of: {}".format(droneNum,droneDist[droneNum]))
    padding=longestDistance-droneDist[droneNum]
    if padding>longestDistance:
        print("Something is broken: Padding:{} is greater than total sim time{}. Delta:{}".format(padding,calc.currentTime(),calc.currentTime()-padding))
        #print("Longest drone detail:")
        #for i in range(Log.getQty()):
        #    line=log[i].getLine().split()
        #    #print (line)
        #    if int(line[0])==(longestDrone):
        #        print("Line: {} ".format(line)) 
        #raise SystemExit("Error 999:Stop right there!") 
    if padding>0:
        print("Drone {} needs to be padded by: {}".format(droneNum,padding))   
        log.append( (str(droneNum)+" W "+str(padding)))         
        
#Write the output file
#Log.getCount()
outputFile = open("submission.csv", "w")
#outputFile = open("/kaggle/working/submission.csv", "w")

result=outputFile.write( str( len(log) )+'\n'  )
for i in range(len(log)):
    result=outputFile.write(log[i]+'\n')

outputFile.close()
# Out:
# Warehouse 0
# Warehouse 1
# Warehouse 2
# Warehouse 3
# Warehouse 4
# Warehouse 5
# Warehouse 6
# Warehouse 7
# Warehouse 8
# Warehouse 9
#
#
#
# ordArrayMaster doesnt exist yet. Make a master and a copy
# ic| fileWithPath: './models/1671822393/500000'
# Wrapping the env in a DummyVecEnv.
# All orders completed! (9368) in 3197 manifest steps
# Drone:7 was the last to finish. The finish time was:18898
# Padding drone:0 with 94326 units of time
# Padding drone:1 with 94443 units of time
# Padding drone:2 with 94380 units of time
# Padding drone:3 with 94286 units of time
# Padding drone:4 with 94240 units of time
# Padding drone:5 with 94477 units of time
# Padding drone:6 with 94341 units of time
# Padding drone:7 with 94095 units of time
# Padding drone:8 with 94478 units of time
# Padding drone:9 with 94362 units of time
# Padding drone:10 with 94228 units of time
# Padding drone:11 with 94469 units of time
# Padding drone:12 with 94217 units of time
# Padding drone:13 with 94181 units of time
# Padding drone:14 with 94201 units of time
# Padding drone:15 with 94476 units of time
# Padding drone:16 with 94465 units of time
# Padding drone:17 with 94288 units of time
# Padding drone:18 with 94447 units of time
# Padding drone:19 with 94127 units of time
# Padding drone:20 with 94301 units of time
# Padding drone:21 with 94328 units of time
# Padding drone:22 with 94464 units of time
# Padding drone:23 with 94219 units of time
# Padding drone:24 with 94401 units of time
# Padding drone:25 with 94324 units of time
# Padding drone:26 with 94489 units of time
# Padding drone:27 with 94420 units of time
# Padding drone:28 with 94284 units of time
# Padding drone:29 with 94201 units of time
# --- 180.9420130252838 seconds ---
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Stop right there!
# C:\Users\greg\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3441: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
destTime,droneNum=min([  (d[x].getDestTime(),ind) for ind,x in enumerate(  range( Drone.getQty() )  ) ])

droneNum
#[(i, j) for i, j in enumerate(mylist)]
# Out:
# 1

# %%
min([d[x].getDestTime() for x in range(Drone.getQty())])
# Out:
# 0

# %%
deadline
# Out:
# 99999
